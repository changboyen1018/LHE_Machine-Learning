# %% [markdown]
# # **Homework 10 - Adversarial Attack**

# %% [markdown]
# ## Enviroment & Download
#
# We make use of [pytorchcv](https://pypi.org/project/pytorchcv/) to obtain CIFAR-10 pretrained model, so we need to set up the enviroment first. We also need to download the data (200 images) which we want to attack.

# %%
# set up environment
# !pip install pytorchcv
# !pip install imgaug

# download
# !gdown --id 1t2UFQXr1cr5qLMBK2oN2rY1NDypi9Nyw --output data.zip

# if the above link isn't available, try this one
# !wget https://www.dropbox.com/s/lbpypqamqjpt2qz/data.zip

# unzip
# !unzip ./data.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorchcv
#   Downloading pytorchcv-0.0.67-py2.py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.4/532.4 kB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorchcv) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pytorchcv) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pytorchcv) (3.4)
# Installing collected packages: pytorchcv
# Successfully installed pytorchcv-0.0.67
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.10.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug) (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug) (4.7.0.72)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.25.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.0.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (3.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (2.8.2)
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1t2UFQXr1cr5qLMBK2oN2rY1NDypi9Nyw
# To: /content/data.zip
# 100% 490k/490k [00:00<00:00, 115MB/s]
# Archive:  ./data.zip
#    creating: data/
#    creating: data/deer/
#  extracting: data/deer/deer13.png
#  extracting: data/deer/deer6.png
#  extracting: data/deer/deer11.png
#  extracting: data/deer/deer2.png
#  extracting: data/deer/deer10.png
#  extracting: data/deer/deer16.png
#  extracting: data/deer/deer9.png
#  extracting: data/deer/deer20.png
#  extracting: data/deer/deer15.png
#  extracting: data/deer/deer19.png
#  extracting: data/deer/deer5.png
#  extracting: data/deer/deer14.png
#  extracting: data/deer/deer4.png
#  extracting: data/deer/deer8.png
#  extracting: data/deer/deer12.png
#  extracting: data/deer/deer1.png
#  extracting: data/deer/deer7.png
#  extracting: data/deer/deer17.png
#  extracting: data/deer/deer18.png
#  extracting: data/deer/deer3.png
#    creating: data/horse/
#  extracting: data/horse/horse9.png
#  extracting: data/horse/horse1.png
#  extracting: data/horse/horse16.png
#  extracting: data/horse/horse15.png
#  extracting: data/horse/horse19.png
#  extracting: data/horse/horse14.png
#  extracting: data/horse/horse10.png
#  extracting: data/horse/horse7.png
#  extracting: data/horse/horse2.png
#  extracting: data/horse/horse6.png
#  extracting: data/horse/horse20.png
#  extracting: data/horse/horse5.png
#  extracting: data/horse/horse18.png
#  extracting: data/horse/horse12.png
#  extracting: data/horse/horse13.png
#  extracting: data/horse/horse17.png
#  extracting: data/horse/horse4.png
#  extracting: data/horse/horse11.png
#  extracting: data/horse/horse8.png
#  extracting: data/horse/horse3.png
#    creating: data/ship/
#  extracting: data/ship/ship10.png
#  extracting: data/ship/ship14.png
#  extracting: data/ship/ship9.png
#  extracting: data/ship/ship20.png
#  extracting: data/ship/ship5.png
#  extracting: data/ship/ship8.png
#  extracting: data/ship/ship19.png
#  extracting: data/ship/ship16.png
#  extracting: data/ship/ship13.png
#  extracting: data/ship/ship6.png
#  extracting: data/ship/ship17.png
#  extracting: data/ship/ship1.png
#  extracting: data/ship/ship12.png
#  extracting: data/ship/ship2.png
#  extracting: data/ship/ship3.png
#  extracting: data/ship/ship15.png
#  extracting: data/ship/ship4.png
#  extracting: data/ship/ship7.png
#  extracting: data/ship/ship11.png
#  extracting: data/ship/ship18.png
#    creating: data/frog/
#  extracting: data/frog/frog10.png
#  extracting: data/frog/frog4.png
#  extracting: data/frog/frog5.png
#  extracting: data/frog/frog20.png
#  extracting: data/frog/frog15.png
#  extracting: data/frog/frog3.png
#  extracting: data/frog/frog1.png
#  extracting: data/frog/frog14.png
#  extracting: data/frog/frog2.png
#  extracting: data/frog/frog19.png
#  extracting: data/frog/frog7.png
#  extracting: data/frog/frog11.png
#  extracting: data/frog/frog17.png
#  extracting: data/frog/frog18.png
#  extracting: data/frog/frog12.png
#  extracting: data/frog/frog16.png
#  extracting: data/frog/frog8.png
#  extracting: data/frog/frog13.png
#  extracting: data/frog/frog6.png
#  extracting: data/frog/frog9.png
#    creating: data/airplane/
#  extracting: data/airplane/airplane3.png
#  extracting: data/airplane/airplane4.png
#  extracting: data/airplane/airplane2.png
#  extracting: data/airplane/airplane9.png
#  extracting: data/airplane/airplane20.png
#  extracting: data/airplane/airplane18.png
#  extracting: data/airplane/airplane19.png
#  extracting: data/airplane/airplane10.png
#  extracting: data/airplane/airplane6.png
#  extracting: data/airplane/airplane13.png
#  extracting: data/airplane/airplane16.png
#  extracting: data/airplane/airplane14.png
#  extracting: data/airplane/airplane11.png
#  extracting: data/airplane/airplane1.png
#  extracting: data/airplane/airplane17.png
#  extracting: data/airplane/airplane7.png
#  extracting: data/airplane/airplane15.png
#  extracting: data/airplane/airplane5.png
#  extracting: data/airplane/airplane8.png
#  extracting: data/airplane/airplane12.png
#    creating: data/bird/
#  extracting: data/bird/bird9.png
#  extracting: data/bird/bird12.png
#  extracting: data/bird/bird10.png
#  extracting: data/bird/bird11.png
#  extracting: data/bird/bird5.png
#  extracting: data/bird/bird8.png
#  extracting: data/bird/bird4.png
#  extracting: data/bird/bird3.png
#  extracting: data/bird/bird7.png
#  extracting: data/bird/bird18.png
#  extracting: data/bird/bird14.png
#  extracting: data/bird/bird13.png
#  extracting: data/bird/bird2.png
#  extracting: data/bird/bird15.png
#  extracting: data/bird/bird17.png
#  extracting: data/bird/bird19.png
#  extracting: data/bird/bird16.png
#  extracting: data/bird/bird6.png
#  extracting: data/bird/bird20.png
#  extracting: data/bird/bird1.png
#    creating: data/cat/
#  extracting: data/cat/cat6.png
#  extracting: data/cat/cat1.png
#  extracting: data/cat/cat7.png
#  extracting: data/cat/cat19.png
#  extracting: data/cat/cat5.png
#  extracting: data/cat/cat9.png
#  extracting: data/cat/cat17.png
#  extracting: data/cat/cat2.png
#  extracting: data/cat/cat16.png
#  extracting: data/cat/cat10.png
#  extracting: data/cat/cat4.png
#  extracting: data/cat/cat18.png
#  extracting: data/cat/cat13.png
#  extracting: data/cat/cat11.png
#  extracting: data/cat/cat20.png
#  extracting: data/cat/cat15.png
#  extracting: data/cat/cat8.png
#  extracting: data/cat/cat14.png
#  extracting: data/cat/cat3.png
#  extracting: data/cat/cat12.png
#    creating: data/automobile/
#  extracting: data/automobile/automobile17.png
#  extracting: data/automobile/automobile11.png
#  extracting: data/automobile/automobile5.png
#  extracting: data/automobile/automobile10.png
#  extracting: data/automobile/automobile20.png
#  extracting: data/automobile/automobile2.png
#  extracting: data/automobile/automobile6.png
#  extracting: data/automobile/automobile1.png
#  extracting: data/automobile/automobile19.png
#  extracting: data/automobile/automobile7.png
#  extracting: data/automobile/automobile16.png
#  extracting: data/automobile/automobile3.png
#  extracting: data/automobile/automobile14.png
#  extracting: data/automobile/automobile12.png
#  extracting: data/automobile/automobile9.png
#  extracting: data/automobile/automobile4.png
#  extracting: data/automobile/automobile8.png
#  extracting: data/automobile/automobile13.png
#  extracting: data/automobile/automobile18.png
#  extracting: data/automobile/automobile15.png
#    creating: data/dog/
#  extracting: data/dog/dog9.png
#  extracting: data/dog/dog2.png
#  extracting: data/dog/dog15.png
#  extracting: data/dog/dog8.png
#  extracting: data/dog/dog3.png
#  extracting: data/dog/dog19.png
#  extracting: data/dog/dog12.png
#  extracting: data/dog/dog7.png
#  extracting: data/dog/dog17.png
#  extracting: data/dog/dog11.png
#  extracting: data/dog/dog16.png
#  extracting: data/dog/dog20.png
#  extracting: data/dog/dog4.png
#  extracting: data/dog/dog5.png
#  extracting: data/dog/dog14.png
#  extracting: data/dog/dog18.png
#  extracting: data/dog/dog10.png
#  extracting: data/dog/dog1.png
#  extracting: data/dog/dog13.png
#  extracting: data/dog/dog6.png
#    creating: data/truck/
#  extracting: data/truck/truck1.png
#  extracting: data/truck/truck18.png
#  extracting: data/truck/truck9.png
#  extracting: data/truck/truck4.png
#  extracting: data/truck/truck14.png
#  extracting: data/truck/truck8.png
#  extracting: data/truck/truck12.png
#  extracting: data/truck/truck15.png
#  extracting: data/truck/truck2.png
#  extracting: data/truck/truck5.png
#  extracting: data/truck/truck3.png
#  extracting: data/truck/truck10.png
#  extracting: data/truck/truck17.png
#  extracting: data/truck/truck20.png
#  extracting: data/truck/truck19.png
#  extracting: data/truck/truck13.png
#  extracting: data/truck/truck7.png
#  extracting: data/truck/truck6.png
#   inflating: data/truck/truck16.png
#  extracting: data/truck/truck11.png

# %%
# !rm ./data.zip

# %%
import torch
import torch.nn as nn
from pytorchcv.model_provider import get_model as ptcv_get_model
import random
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 8

def same_seeds(seed):
	  torch.manual_seed(seed)
	  if torch.cuda.is_available():
		    torch.cuda.manual_seed(seed)
		    torch.cuda.manual_seed_all(seed)
	  np.random.seed(seed)
	  random.seed(seed)
	  torch.backends.cudnn.benchmark = False
	  torch.backends.cudnn.deterministic = True
same_seeds(0) ##

# %% [markdown]
# ## Global Settings
# #### **[NOTE]**: Don't change the settings here, or your generated image might not meet the constraint.
# * $\epsilon$ is fixed to be 8. But on **Data section**, we will first apply transforms on raw pixel value (0-255 scale) **by ToTensor (to 0-1 scale)** and then **Normalize (subtract mean divide std)**. $\epsilon$ should be set to $\frac{8}{255 * std}$ during attack.
#
# * Explaination (optional)
#     * Denote the first pixel of original image as $p$, and the first pixel of adversarial image as $a$.
#     * The $\epsilon$ constraints tell us $\left| p-a \right| <= 8$.
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#     * After applying ToTensor() and Normalize() on $p$ and $a$, the constraint becomes $\left| N(T(p))-N(T(a)) \right| = \left| \frac{\frac{p}{255}-mean}{std}-\frac{\frac{a}{255}-mean}{std} \right| = \frac{1}{255 * std} \left| p-a \right| <= \frac{8}{255 * std}.$
#     * So, we should set $\epsilon$ to be $\frac{8}{255 * std}$ after ToTensor() and Normalize().

# %%
# the mean and std are the calculated statistics from cifar_10 dataset
cifar_10_mean = (0.491, 0.482, 0.447) # mean for the three channels of cifar_10 images
cifar_10_std = (0.202, 0.199, 0.201) # std for the three channels of cifar_10 images

# convert mean and std to 3-dimensional tensors for future operations
mean = torch.tensor(cifar_10_mean).to(device).view(3, 1, 1)
std = torch.tensor(cifar_10_std).to(device).view(3, 1, 1)

epsilon = 8/255/std

# %%
root = './data' # directory for storing benign images
# benign images: images which do not contain adversarial perturbations
# adversarial images: images which include adversarial perturbations

# %% [markdown]
# ## Data
#
# Construct dataset and dataloader from root directory. Note that we store the filename of each image for future usage.

# %%
import os
import glob
import shutil
import numpy as np
from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_10_mean, cifar_10_std)
])

class AdvDataset(Dataset):
    def __init__(self, data_dir, transform):
        self.images = []
        self.labels = []
        self.names = []
        '''
        data_dir
        ├── class_dir
        │   ├── class1.png
        │   ├── ...
        │   ├── class20.png
        '''
        for i, class_dir in enumerate(sorted(glob.glob(f'{data_dir}/*'))):
            images = sorted(glob.glob(f'{class_dir}/*'))
            self.images += images
            self.labels += ([i] * len(images))
            self.names += [os.path.relpath(imgs, data_dir) for imgs in images]
        self.transform = transform
    def __getitem__(self, idx):
        image = self.transform(Image.open(self.images[idx]))
        label = self.labels[idx]
        return image, label
    def __getname__(self):
        return self.names
    def __len__(self):
        return len(self.images)

adv_set = AdvDataset(root, transform=transform)
adv_names = adv_set.__getname__()
adv_loader = DataLoader(adv_set, batch_size=batch_size, shuffle=False)

print(f'number of images = {adv_set.__len__()}')
# Out:
# number of images = 200

# %% [markdown]
# ## Utils -- Benign Images Evaluation

# %%
# to evaluate the performance of model on benign images
def epoch_benign(model, loader, loss_fn):
    model.eval()
    train_acc, train_loss = 0.0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        yp = model(x)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
    return train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# %% [markdown]
# ## Utils -- Attack Algorithm

# %%
# perform fgsm attack
def fgsm(model, x, y, loss_fn, epsilon=epsilon):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    loss = loss_fn(model(x_adv), y) # calculate loss
    loss.backward() # calculate gradient
    # fgsm: use gradient ascent on x_adv to maximize loss
    grad = x_adv.grad.detach()
    x_adv = x_adv + epsilon * grad.sign()
    return x_adv

# alpha and num_iter can be decided by yourself
alpha = 0.8/255/std

def ifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20):
    x_adv = x.detach().clone()
    ################ TODO: Medium baseline #######################
    # write a loop with num_iter times
    for i in range(num_iter):
      # TODO: Each iteration, execute fgsm
      pass

    return x_adv

#def mifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20, decay=0.3):
#    x_adv = x.detach().clone().to(device)
#    # initialze momentum tensor
#    momentum = torch.zeros_like(x).detach().to(device)
#
#    ################ TODO: Strong baseline ####################
#    for i in range(num_iter):
#      # TODO: Refer to the algorithm of MI-FGSM
#      # Calculate the momentum and update
#      pass
#    return x_adv

def mifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20, decay=0.3):
    x_adv = x.detach().clone().to(device)
    # initialize momentum tensor
    momentum = torch.zeros_like(x).detach().to(device)

    for i in range(num_iter):
        # set the flag to calculate gradients
        x_adv.requires_grad = True

        # forward pass
        output = model(x_adv)
        loss = loss_fn(output, y)
        
        # zero gradients
        model.zero_grad()

        # backward pass
        if x_adv.grad is not None:
            x_adv.grad.data.fill_(0)
        loss.backward()

        # get the gradient
        grad = x_adv.grad.detach()

        # normalize the gradient
        grad_norm = torch.norm(nn.Flatten()(grad), p=2, dim=1).view(-1, 1, 1, 1)
        grad = grad / grad_norm

        # update the momentum
        momentum = decay * momentum + grad

        # update adversarial example
        x_adv = x_adv + alpha * momentum.sign()

        # clip to ensure within epsilon ball and valid image
        x_adv = torch.max(torch.min(x_adv, x + epsilon), x - epsilon)
        x_adv = torch.clamp(x_adv, 0, 1).detach()

    return x_adv

# %% [markdown]
# ## Utils -- Attack
# * Recall
#   * ToTensor() can be seen as a function where $T(x) = x/255$.
#   * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#
# * Inverse function
#   * Inverse Normalize() can be seen as a function where $N^{-1}(x) = x*std+mean$ where $mean$ and $std$ are constants.
#   * Inverse ToTensor() can be seen as a function where $T^{-1}(x) = x*255$.
#
# * Special Noted
#   * ToTensor() will also convert the image from shape (height, width, channel) to shape (channel, height, width), so we also need to transpose the shape back to original shape.
#   * Since our dataloader samples a batch of data, what we need here is to transpose **(batch_size, channel, height, width)** back to **(batch_size, height, width, channel)** using np.transpose.

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8)) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %%
# DIM-MIFGSM 參考此連結以及ChatGPT撰寫 # https://github.com/Harry24k/adversarial-attacks-pytorch/blob/master/torchattacks/attacks/difgsm.py

import torch
from torch.nn import functional as F

def input_diversity(x, resize_rate=0.9, diversity_prob=0.5):
    """
    對輸入的圖像實現多樣化。具體操作為先隨機縮放圖像，然後在圖像周圍補零。
    如果隨機數大於 diversity_prob，則返回原始圖像。

    參數：
        x : 輸入圖像
        resize_rate : 圖像縮放比例
        diversity_prob : 圖像多樣化的概率
    """
    img_size = x.shape[-1]
    img_resize = int(img_size * resize_rate)

    if resize_rate < 1:
        img_size, img_resize = img_resize, img_size

    rnd = torch.randint(low=img_size, high=img_resize, size=(1,), dtype=torch.int32)
    rescaled = F.interpolate(x, size=[rnd, rnd], mode='bilinear', align_corners=False)

    h_rem, w_rem = img_resize - rnd, img_resize - rnd
    pad_top = torch.randint(low=0, high=h_rem.item(), size=(1,), dtype=torch.int32)
    pad_bottom, pad_left = h_rem - pad_top, torch.randint(low=0, high=w_rem.item(), size=(1,), dtype=torch.int32)
    pad_right = w_rem - pad_left

    padded = F.pad(rescaled, [pad_left.item(), pad_right.item(), pad_top.item(), pad_bottom.item()], value=0)

    return padded if torch.rand(1) < diversity_prob else x

def dmifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=40, decay=1.0, resize_rate=0.9, diversity_prob=0.5):
    """
    執行 DIM-MIFGSM 攻擊。

    參數：
        model : 被攻擊的模型
        x : 輸入圖像
        y : 圖像的標籤
        loss_fn : 損失函數
        epsilon : FGSM 攻擊的最大擾動
        alpha : 攻擊步長
        num_iter : 迭代次數
        decay : 力度衰減
        resize_rate : 圖像縮放比例
        diversity_prob : 圖像多樣化的概率
    """
    x_adv = x
    momentum = torch.zeros_like(x).detach().to(device)

    for _ in range(num_iter):
        x_adv = x_adv.detach().clone()
        x_adv.requires_grad = True
        loss = loss_fn(model(input_diversity(x_adv, resize_rate, diversity_prob)), y)
        loss.backward()

        grad = x_adv.grad.detach()
        grad_norm = torch.mean(torch.abs(grad), dim=(1,2,3), keepdim=True)
        grad = grad / grad_norm + momentum * decay
        momentum = grad

        x_adv = x_adv + alpha * grad.sign()
        x_adv = torch.max(torch.min(x_adv, x + epsilon), x - epsilon)

    return x_adv

# %% [markdown]
# ## Model / Loss Function
#
# Model list is available [here](https://github.com/osmr/imgclsmob/blob/master/pytorch/pytorchcv/model_provider.py). Please select models which has _cifar10 suffix. Other kinds of models are prohibited, and it will be considered to be cheating if you use them.
#
# Note: Some of the models cannot be accessed/loaded. You can safely skip them since TA's model will not use those kinds of models.

# %%
# This function is used to check whether you use models pretrained on cifar10 instead of other datasets
def model_checker(model_name):
  assert ('cifar10' in model_name) and ('cifar100' not in model_name), 'The model selected is not pretrained on cifar10!'

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

model_name = 'resnet110_cifar10'
model_checker(model_name)

model = ptcv_get_model(model_name, pretrained=True).to(device)
loss_fn = nn.CrossEntropyLoss()

benign_acc, benign_loss = epoch_benign(model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# Downloading /root/.torch/models/resnet110_cifar10-0369-4d6ca1fc.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet110_cifar10-0369-4d6ca1fc.pth.zip...
# benign_acc = 0.95000, benign_loss = 0.22678

# %% [markdown]
# ## FGSM

# %%
adv_examples, fgsm_acc, fgsm_loss = gen_adv_examples(model, adv_loader, fgsm, loss_fn)
print(f'fgsm_acc = {fgsm_acc:.5f}, fgsm_loss = {fgsm_loss:.5f}')

create_dir(root, 'fgsm', adv_examples, adv_names)
# Out:
# fgsm_acc = 0.59000, fgsm_loss = 2.49187

# %%
# %cd fgsm
# !tar zcvf ../fgsm.tgz *
# %cd ..
# Out:
# /content/fgsm
# airplane/
# airplane/airplane18.png
# airplane/airplane8.png
# airplane/airplane2.png
# airplane/airplane6.png
# airplane/airplane17.png
# airplane/airplane1.png
# airplane/airplane10.png
# airplane/airplane15.png
# airplane/airplane19.png
# airplane/airplane14.png
# airplane/airplane3.png
# airplane/airplane13.png
# airplane/airplane16.png
# airplane/airplane12.png
# airplane/airplane4.png
# airplane/airplane5.png
# airplane/airplane9.png
# airplane/airplane11.png
# airplane/airplane20.png
# airplane/airplane7.png
# automobile/
# automobile/automobile2.png
# automobile/automobile11.png
# automobile/automobile14.png
# automobile/automobile12.png
# automobile/automobile1.png
# automobile/automobile5.png
# automobile/automobile9.png
# automobile/automobile15.png
# automobile/automobile7.png
# automobile/automobile17.png
# automobile/automobile4.png
# automobile/automobile20.png
# automobile/automobile8.png
# automobile/automobile16.png
# automobile/automobile10.png
# automobile/automobile19.png
# automobile/automobile18.png
# automobile/automobile3.png
# automobile/automobile13.png
# automobile/automobile6.png
# bird/
# bird/bird14.png
# bird/bird11.png
# bird/bird8.png
# bird/bird13.png
# bird/bird16.png
# bird/bird18.png
# bird/bird19.png
# bird/bird7.png
# bird/bird15.png
# bird/bird2.png
# bird/bird9.png
# bird/bird4.png
# bird/bird12.png
# bird/bird3.png
# bird/bird10.png
# bird/bird6.png
# bird/bird1.png
# bird/bird20.png
# bird/bird5.png
# bird/bird17.png
# cat/
# cat/cat19.png
# cat/cat20.png
# cat/cat1.png
# cat/cat2.png
# cat/cat8.png
# cat/cat6.png
# cat/cat12.png
# cat/cat14.png
# cat/cat18.png
# cat/cat7.png
# cat/cat5.png
# cat/cat3.png
# cat/cat9.png
# cat/cat17.png
# cat/cat4.png
# cat/cat10.png
# cat/cat16.png
# cat/cat13.png
# cat/cat15.png
# cat/cat11.png
# deer/
# deer/deer14.png
# deer/deer3.png
# deer/deer1.png
# deer/deer16.png
# deer/deer6.png
# deer/deer15.png
# deer/deer19.png
# deer/deer9.png
# deer/deer12.png
# deer/deer7.png
# deer/deer2.png
# deer/deer8.png
# deer/deer5.png
# deer/deer13.png
# deer/deer18.png
# deer/deer10.png
# deer/deer17.png
# deer/deer11.png
# deer/deer4.png
# deer/deer20.png
# dog/
# dog/dog12.png
# dog/dog16.png
# dog/dog3.png
# dog/dog9.png
# dog/dog6.png
# dog/dog8.png
# dog/dog4.png
# dog/dog7.png
# dog/dog1.png
# dog/dog10.png
# dog/dog2.png
# dog/dog19.png
# dog/dog15.png
# dog/dog14.png
# dog/dog13.png
# dog/dog20.png
# dog/dog17.png
# dog/dog11.png
# dog/dog5.png
# dog/dog18.png
# frog/
# frog/frog3.png
# frog/frog11.png
# frog/frog13.png
# frog/frog14.png
# frog/frog6.png
# frog/frog15.png
# frog/frog17.png
# frog/frog2.png
# frog/frog5.png
# frog/frog18.png
# frog/frog10.png
# frog/frog8.png
# frog/frog16.png
# frog/frog9.png
# frog/frog12.png
# frog/frog4.png
# frog/frog1.png
# frog/frog7.png
# frog/frog20.png
# frog/frog19.png
# horse/
# horse/horse1.png
# horse/horse17.png
# horse/horse2.png
# horse/horse16.png
# horse/horse15.png
# horse/horse18.png
# horse/horse11.png
# horse/horse19.png
# horse/horse20.png
# horse/horse8.png
# horse/horse9.png
# horse/horse10.png
# horse/horse14.png
# horse/horse4.png
# horse/horse5.png
# horse/horse13.png
# horse/horse3.png
# horse/horse12.png
# horse/horse7.png
# horse/horse6.png
# ship/
# ship/ship10.png
# ship/ship9.png
# ship/ship3.png
# ship/ship20.png
# ship/ship1.png
# ship/ship8.png
# ship/ship19.png
# ship/ship15.png
# ship/ship12.png
# ship/ship14.png
# ship/ship11.png
# ship/ship7.png
# ship/ship13.png
# ship/ship5.png
# ship/ship16.png
# ship/ship6.png
# ship/ship2.png
# ship/ship18.png
# ship/ship17.png
# ship/ship4.png
# truck/
# truck/truck16.png
# truck/truck13.png
# truck/truck18.png
# truck/truck6.png
# truck/truck20.png
# truck/truck10.png
# truck/truck17.png
# truck/truck11.png
# truck/truck2.png
# truck/truck8.png
# truck/truck4.png
# truck/truck14.png
# truck/truck9.png
# truck/truck19.png
# truck/truck12.png
# truck/truck5.png
# truck/truck7.png
# truck/truck3.png
# truck/truck15.png
# truck/truck1.png
# /content

# %%
from google.colab import files
files.download('fgsm.tgz')

# %% [markdown]
# ## Example of Ensemble Attack
# * Ensemble multiple models as your proxy model to increase the black-box transferability ([paper](https://arxiv.org/abs/1611.02770))

# %%
################ BOSS BASELINE ######################

##

class ensembleNet(nn.Module):
    def __init__(self, model_names):
        super().__init__()
        self.models = nn.ModuleList([ptcv_get_model(name, pretrained=True) for name in model_names])
        
    def forward(self, x):
        ensemble_logits = 0
        #################### TODO: boss baseline ###################
        for i, m in enumerate(self.models):
          
        # TODO: sum up logits from multiple models  
        # return ensemble_logits
          logits = m(x.clone())
          ensemble_logits += logits
          ensemble_logits = ensemble_logits / len(self.models)
        return ensemble_logits

# %% [markdown]
# * Construct your ensemble model

# %%
model_names = [
    'nin_cifar10',
    #'resnext20_16x4d_cifar10',
    'seresnet20_cifar10', 
    'seresnet56_cifar10', 
    #'fractalnet_cifar10',
    'preresnet20_cifar10', 
    'preresnet56_cifar10',
    #'resdropresnet20_cifar10',
    'sepreresnet20_cifar10',
    'sepreresnet56_cifar10',
    #'shakedropresnet20_cifar10',
    'diaresnet20_cifar10',
    'diaresnet56_cifar10',
    #'msdnet22_cifar10',

    'resnet20_cifar10',
    'resnet56_cifar10', 

]

#for model_name in model_names:
#  model_checker(model_name)

ensemble_model = ensembleNet(model_names).to(device)
ensemble_model.eval()

print()

# %%
import torch.nn as nn

loss_fn = nn.CrossEntropyLoss()

#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#epsilon = 0.1
#alpha = 0.01

#have already defined and trained your ensemble_model and set up your adv_loader
benign_acc, benign_loss = epoch_benign(ensemble_model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')

ATTACK_METHOD_STR = "dmifgsm"

# 將dmifgsm包裝在一個lambda函數中
ATTACK_METHOD = dmifgsm


adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples(ensemble_model, adv_loader, ATTACK_METHOD, loss_fn)
print(f'{ATTACK_METHOD_STR}_acc = {ifgsm_acc:.5f}, {ATTACK_METHOD_STR}_loss = {ifgsm_loss:.5f}')

create_dir(root, ATTACK_METHOD_STR, adv_examples, adv_names)
# Out:
# benign_acc = 0.95000, benign_loss = 1.30429
# dmifgsm_acc = 0.03000, dmifgsm_loss = 3.23750

# %%
# !ls
# %cd dmifgsm
# !tar zcvf ../dmifgsm.tgz *
# %cd ..
# Out:
# data  dmifgsm  dmifgsm.tgz  sample_data
# /content/dmifgsm
# airplane/
# airplane/airplane18.png
# airplane/airplane8.png
# airplane/airplane2.png
# airplane/airplane6.png
# airplane/airplane17.png
# airplane/airplane1.png
# airplane/airplane10.png
# airplane/airplane15.png
# airplane/airplane19.png
# airplane/airplane14.png
# airplane/airplane3.png
# airplane/airplane13.png
# airplane/airplane16.png
# airplane/airplane12.png
# airplane/airplane4.png
# airplane/airplane5.png
# airplane/airplane9.png
# airplane/airplane11.png
# airplane/airplane20.png
# airplane/airplane7.png
# automobile/
# automobile/automobile2.png
# automobile/automobile11.png
# automobile/automobile14.png
# automobile/automobile12.png
# automobile/automobile1.png
# automobile/automobile5.png
# automobile/automobile9.png
# automobile/automobile15.png
# automobile/automobile7.png
# automobile/automobile17.png
# automobile/automobile4.png
# automobile/automobile20.png
# automobile/automobile8.png
# automobile/automobile16.png
# automobile/automobile10.png
# automobile/automobile19.png
# automobile/automobile18.png
# automobile/automobile3.png
# automobile/automobile13.png
# automobile/automobile6.png
# bird/
# bird/bird14.png
# bird/bird11.png
# bird/bird8.png
# bird/bird13.png
# bird/bird16.png
# bird/bird18.png
# bird/bird19.png
# bird/bird7.png
# bird/bird15.png
# bird/bird2.png
# bird/bird9.png
# bird/bird4.png
# bird/bird12.png
# bird/bird3.png
# bird/bird10.png
# bird/bird6.png
# bird/bird1.png
# bird/bird20.png
# bird/bird5.png
# bird/bird17.png
# cat/
# cat/cat19.png
# cat/cat20.png
# cat/cat1.png
# cat/cat2.png
# cat/cat8.png
# cat/cat6.png
# cat/cat12.png
# cat/cat14.png
# cat/cat18.png
# cat/cat7.png
# cat/cat5.png
# cat/cat3.png
# cat/cat9.png
# cat/cat17.png
# cat/cat4.png
# cat/cat10.png
# cat/cat16.png
# cat/cat13.png
# cat/cat15.png
# cat/cat11.png
# deer/
# deer/deer14.png
# deer/deer3.png
# deer/deer1.png
# deer/deer16.png
# deer/deer6.png
# deer/deer15.png
# deer/deer19.png
# deer/deer9.png
# deer/deer12.png
# deer/deer7.png
# deer/deer2.png
# deer/deer8.png
# deer/deer5.png
# deer/deer13.png
# deer/deer18.png
# deer/deer10.png
# deer/deer17.png
# deer/deer11.png
# deer/deer4.png
# deer/deer20.png
# dog/
# dog/dog12.png
# dog/dog16.png
# dog/dog3.png
# dog/dog9.png
# dog/dog6.png
# dog/dog8.png
# dog/dog4.png
# dog/dog7.png
# dog/dog1.png
# dog/dog10.png
# dog/dog2.png
# dog/dog19.png
# dog/dog15.png
# dog/dog14.png
# dog/dog13.png
# dog/dog20.png
# dog/dog17.png
# dog/dog11.png
# dog/dog5.png
# dog/dog18.png
# frog/
# frog/frog3.png
# frog/frog11.png
# frog/frog13.png
# frog/frog14.png
# frog/frog6.png
# frog/frog15.png
# frog/frog17.png
# frog/frog2.png
# frog/frog5.png
# frog/frog18.png
# frog/frog10.png
# frog/frog8.png
# frog/frog16.png
# frog/frog9.png
# frog/frog12.png
# frog/frog4.png
# frog/frog1.png
# frog/frog7.png
# frog/frog20.png
# frog/frog19.png
# horse/
# horse/horse1.png
# horse/horse17.png
# horse/horse2.png
# horse/horse16.png
# horse/horse15.png
# horse/horse18.png
# horse/horse11.png
# horse/horse19.png
# horse/horse20.png
# horse/horse8.png
# horse/horse9.png
# horse/horse10.png
# horse/horse14.png
# horse/horse4.png
# horse/horse5.png
# horse/horse13.png
# horse/horse3.png
# horse/horse12.png
# horse/horse7.png
# horse/horse6.png
# ship/
# ship/ship10.png
# ship/ship9.png
# ship/ship3.png
# ship/ship20.png
# ship/ship1.png
# ship/ship8.png
# ship/ship19.png
# ship/ship15.png
# ship/ship12.png
# ship/ship14.png
# ship/ship11.png
# ship/ship7.png
# ship/ship13.png
# ship/ship5.png
# ship/ship16.png
# ship/ship6.png
# ship/ship2.png
# ship/ship18.png
# ship/ship17.png
# ship/ship4.png
# truck/
# truck/truck16.png
# truck/truck13.png
# truck/truck18.png
# truck/truck6.png
# truck/truck20.png
# truck/truck10.png
# truck/truck17.png
# truck/truck11.png
# truck/truck2.png
# truck/truck8.png
# truck/truck4.png
# truck/truck14.png
# truck/truck9.png
# truck/truck19.png
# truck/truck12.png
# truck/truck5.png
# truck/truck7.png
# truck/truck3.png
# truck/truck15.png
# truck/truck1.png
# /content

# %%
from google.colab import files
files.download('dmifgsm.tgz')

# %%
# !ls
# %cd mifgsm
# !tar zcvf ../mifgsm.tgz *
# %cd ..
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# usr/lib64-nvidia/libnvidia-glsi.so.525.85.12
# usr/lib64-nvidia/libGLESv1_CM.so.1.2.0
# usr/lib64-nvidia/libcuda.so.1
# usr/lib64-nvidia/libGLX.so
# usr/lib64-nvidia/libGLX_indirect.so.0
# usr/lib64-nvidia/libGLX_nvidia.so.525.85.12
# usr/lib64-nvidia/libnvidia-nvvm.so.4
# usr/lib64-nvidia/libcudadebugger.so.1
# usr/lib64-nvidia/libnvidia-glcore.so.525.85.12
# usr/lib64-nvidia/libnvcuvid.so.1
# usr/lib64-nvidia/libOpenCL.so
# usr/lib64-nvidia/libEGL.so.1.1.0
# usr/lib64-nvidia/libEGL_nvidia.so.0
# usr/lib64-nvidia/libcudadebugger.so.525.85.12
# usr/lib64-nvidia/libnvidia-nvvm.so.525.85.12
# usr/lib64-nvidia/libOpenCL.so.1
# usr/lib64-nvidia/libnvidia-ngx.so.1
# usr/lib64-nvidia/libnvidia-encode.so.1
# usr/lib64-nvidia/libGL.so.1.7.0
# usr/lib64-nvidia/libOpenCL.so.1.0.0
# usr/lib64-nvidia/libvdpau_nvidia.so
# usr/lib64-nvidia/libnvidia-egl-wayland.so.1.1.10
# usr/lib64-nvidia/libnvidia-ml.so.525.85.12
# usr/lib64-nvidia/libnvcuvid.so.525.85.12
# usr/lib64-nvidia/libnvidia-ml.so
# usr/lib64-nvidia/libGLdispatch.so.0
# usr/lib64-nvidia/libnvidia-ptxjitcompiler.so
# usr/lib64-nvidia/libnvidia-opencl.so.525.85.12
# usr/lib64-nvidia/libnvidia-nvvm.so
# usr/lib64-nvidia/libGLX_nvidia.so.0
# usr/lib64-nvidia/vdpau/
# usr/lib64-nvidia/vdpau/libvdpau_nvidia.so.525.85.12
# usr/lib64-nvidia/vdpau/libvdpau_nvidia.so.1
# usr/lib64-nvidia/libnvidia-ngx.so.525.85.12
# usr/lib64-nvidia/libGLESv1_CM_nvidia.so.525.85.12
# usr/lib64-nvidia/libnvidia-rtcore.so.525.85.12
# usr/lib64-nvidia/libnvoptix.so.525.85.12
# usr/lib64-nvidia/libnvidia-opticalflow.so.525.85.12
# usr/lib64-nvidia/libnvidia-cfg.so.1
# usr/lib64-nvidia/libEGL_nvidia.so.525.85.12
# usr/lib64-nvidia/libnvidia-glvkspirv.so.525.85.12
# usr/lib64-nvidia/libnvidia-ml.so.1
# usr/lib64-nvidia/libEGL.so
# usr/lib64-nvidia/libGL.so
# usr/lib64-nvidia/libGLESv2.so
# usr/lib64-nvidia/libcuda.so
# usr/lib64-nvidia/libnvidia-fbc.so.525.85.12
# usr/lib64-nvidia/libnvidia-fbc.so.1
# usr/lib64-nvidia/libOpenCL.so.1.0
# usr/lib64-nvidia/libnvidia-fbc.so
# usr/lib64-nvidia/libGLESv2_nvidia.so.2
# usr/lib64-nvidia/libnvidia-allocator.so.1
# usr/lib64-nvidia/libnvidia-egl-gbm.so.1
# usr/lib64-nvidia/libnvidia-cfg.so
# usr/lib64-nvidia/libnvidia-cfg.so.525.85.12
# usr/lib64-nvidia/libcuda.so.525.85.12
# usr/lib64-nvidia/libnvcuvid.so
# usr/lib64-nvidia/libnvidia-ptxjitcompiler.so.525.85.12
# usr/lib64-nvidia/libnvidia-ptxjitcompiler.so.1
# usr/colab/
# usr/colab/bin/
# usr/colab/bin/language_service
# usr/colab/bin/kernel_manager_proxy
# usr/grte/
# usr/grte/v4/
# usr/grte/v4/lib64/
# usr/grte/v4/lib64/locale/
# usr/grte/v4/lib64/locale/locale-archive
# usr/grte/v5/
# usr/grte/v5/lib64/
# usr/grte/v5/lib64/locale/
# usr/grte/v5/lib64/locale/locale-archive
# usr/libexec/
# usr/libexec/dconf-service
# usr/libexec/glib-pacrunner
# var/
# var/tmp/
# var/backups/
# var/spool/
# var/spool/mail
# var/run
# var/lib/
# var/lib/misc/
# var/lib/apt/
# var/lib/apt/extended_states
# var/lib/apt/mirrors/
# var/lib/apt/mirrors/partial/
# var/lib/apt/lists/
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-updates_InRelease
# var/lib/apt/lists/developer.download.nvidia.com_compute_cuda_repos_ubuntu2004_x86%5f64_InRelease
# var/lib/apt/lists/ppa.launchpad.net_c2d4u.team_c2d4u4.0+_ubuntu_dists_focal_InRelease
# var/lib/apt/lists/auxfiles/
# var/lib/apt/lists/ppa.launchpad.net_ubuntugis_ppa_ubuntu_dists_focal_InRelease
# var/lib/apt/lists/ppa.launchpad.net_deadsnakes_ppa_ubuntu_dists_focal_InRelease
# var/lib/apt/lists/ppa.launchpad.net_graphics-drivers_ppa_ubuntu_dists_focal_InRelease
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-backports_InRelease
# var/lib/apt/lists/ppa.launchpad.net_cran_libgit2_ubuntu_dists_focal_InRelease
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal_InRelease
# var/lib/apt/lists/cloud.r-project.org_bin_linux_ubuntu_focal-cran40_InRelease
# var/lib/apt/lists/partial/
# var/lib/apt/lists/security.ubuntu.com_ubuntu_dists_focal-security_InRelease
# var/lib/apt/lists/lock
# var/lib/apt/lists/ppa.launchpad.net_ubuntugis_ppa_ubuntu_dists_focal_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-updates_multiverse_binary-amd64_Packages.lz4
# var/lib/apt/lists/ppa.launchpad.net_graphics-drivers_ppa_ubuntu_dists_focal_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/ppa.launchpad.net_c2d4u.team_c2d4u4.0+_ubuntu_dists_focal_main_source_Sources.lz4
# var/lib/apt/lists/cloud.r-project.org_bin_linux_ubuntu_focal-cran40_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-backports_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-backports_universe_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal_multiverse_binary-amd64_Packages.lz4
# var/lib/apt/lists/ppa.launchpad.net_cran_libgit2_ubuntu_dists_focal_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/security.ubuntu.com_ubuntu_dists_focal-security_multiverse_binary-amd64_Packages.lz4
# var/lib/apt/lists/security.ubuntu.com_ubuntu_dists_focal-security_universe_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-updates_restricted_binary-amd64_Packages.lz4
# var/lib/apt/lists/ppa.launchpad.net_c2d4u.team_c2d4u4.0+_ubuntu_dists_focal_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal_universe_binary-amd64_Packages.lz4
# var/lib/apt/lists/security.ubuntu.com_ubuntu_dists_focal-security_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/security.ubuntu.com_ubuntu_dists_focal-security_restricted_binary-amd64_Packages.lz4
# var/lib/apt/lists/developer.download.nvidia.com_compute_cuda_repos_ubuntu2004_x86%5f64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal_restricted_binary-amd64_Packages.lz4
# var/lib/apt/lists/ppa.launchpad.net_deadsnakes_ppa_ubuntu_dists_focal_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-updates_main_binary-amd64_Packages.lz4
# var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_focal-updates_universe_binary-amd64_Packages.lz4
# var/lib/apt/periodic/
# var/lib/dpkg/
# var/lib/dpkg/alternatives/
# var/lib/dpkg/alternatives/rmt
# var/lib/dpkg/alternatives/awk
# var/lib/dpkg/alternatives/pager
# var/lib/dpkg/alternatives/w
# var/lib/dpkg/alternatives/c89
# var/lib/dpkg/alternatives/jstack
# var/lib/dpkg/alternatives/view
# var/lib/dpkg/alternatives/rvim
# var/lib/dpkg/alternatives/rcp
# var/lib/dpkg/alternatives/c99
# var/lib/dpkg/alternatives/libopenblas.so.0-x86_64-linux-gnu
# var/lib/dpkg/alternatives/javac
# var/lib/dpkg/alternatives/automake
# var/lib/dpkg/alternatives/rmic
# var/lib/dpkg/alternatives/serialver
# var/lib/dpkg/alternatives/jdeps
# var/lib/dpkg/alternatives/jrunscript
# var/lib/dpkg/alternatives/jshell
# var/lib/dpkg/alternatives/jmod
# var/lib/dpkg/alternatives/libopenblas.so-x86_64-linux-gnu
# var/lib/dpkg/alternatives/cc
# var/lib/dpkg/alternatives/keytool
# var/lib/dpkg/alternatives/editor
# var/lib/dpkg/alternatives/f95
# var/lib/dpkg/alternatives/mpi
# var/lib/dpkg/alternatives/x-cursor-theme
# var/lib/dpkg/alternatives/python3
# var/lib/dpkg/alternatives/mpirun
# var/lib/dpkg/alternatives/jexec
# var/lib/dpkg/alternatives/jstatd
# var/lib/dpkg/alternatives/liblapack.so.3-x86_64-linux-gnu
# var/lib/dpkg/alternatives/jdb
# var/lib/dpkg/alternatives/mpi-x86_64-linux-gnu
# var/lib/dpkg/alternatives/jmap
# var/lib/dpkg/alternatives/libpsm_infinipath.so.1
# var/lib/dpkg/alternatives/write
# var/lib/dpkg/alternatives/jcmd
# var/lib/dpkg/alternatives/libblas.so-x86_64-linux-gnu
# var/lib/dpkg/alternatives/jdeprscan
# var/lib/dpkg/alternatives/rlogin
# var/lib/dpkg/alternatives/javadoc
# var/lib/dpkg/alternatives/liblapack.so-x86_64-linux-gnu
# var/lib/dpkg/alternatives/jps
# var/lib/dpkg/alternatives/jar
# var/lib/dpkg/alternatives/jarsigner
# var/lib/dpkg/alternatives/jinfo
# var/lib/dpkg/alternatives/rsh
# var/lib/dpkg/alternatives/jhsdb
# var/lib/dpkg/alternatives/libblas.so.3-x86_64-linux-gnu
# var/lib/dpkg/alternatives/unpack200
# var/lib/dpkg/alternatives/jimage
# var/lib/dpkg/alternatives/javap
# var/lib/dpkg/alternatives/c++
# var/lib/dpkg/alternatives/from
# var/lib/dpkg/alternatives/my.cnf
# var/lib/dpkg/alternatives/java
# var/lib/dpkg/alternatives/jlink
# var/lib/dpkg/alternatives/vi
# var/lib/dpkg/alternatives/jstat
# var/lib/dpkg/alternatives/ex
# var/lib/dpkg/alternatives/f77
# var/lib/dpkg/alternatives/vimdiff
# var/lib/dpkg/alternatives/hdf5.pc
# var/lib/dpkg/alternatives/unrar
# var/lib/dpkg/alternatives/rename
# var/lib/dpkg/alternatives/vim
# var/lib/dpkg/alternatives/jaotc
# var/lib/dpkg/alternatives/rmid
# var/lib/dpkg/alternatives/jfr
# var/lib/dpkg/alternatives/jjs
# var/lib/dpkg/alternatives/rview
# var/lib/dpkg/alternatives/pack200
# var/lib/dpkg/alternatives/rmiregistry
# var/lib/dpkg/alternatives/libcudnn
# var/lib/dpkg/alternatives/lzma
# var/lib/dpkg/alternatives/cpp
# var/lib/dpkg/alternatives/cufile.json
# var/lib/dpkg/alternatives/cuda-11
# var/lib/dpkg/alternatives/cuda
# var/lib/dpkg/alternatives/pinentry
# var/lib/dpkg/diversions
# var/lib/dpkg/lock-frontend
# var/lib/dpkg/statoverride
# var/lib/dpkg/info/
# var/lib/dpkg/info/base-passwd.postrm
# var/lib/dpkg/info/libseccomp2:amd64.md5sums
# var/lib/dpkg/info/adduser.md5sums
# var/lib/dpkg/info/libtasn1-6:amd64.symbols
# var/lib/dpkg/info/login.conffiles
# var/lib/dpkg/info/libattr1:amd64.md5sums
# var/lib/dpkg/info/libzstd1:amd64.triggers
# var/lib/dpkg/info/libpam-runtime.prerm
# var/lib/dpkg/info/libcrypt1:amd64.triggers
# var/lib/dpkg/info/libncurses6:amd64.shlibs
# var/lib/dpkg/info/libuuid1:amd64.shlibs
# var/lib/dpkg/info/util-linux.md5sums
# var/lib/dpkg/info/libpcre2-8-0:amd64.list
# var/lib/dpkg/info/util-linux.preinst
# var/lib/dpkg/info/libblkid1:amd64.symbols
# var/lib/dpkg/info/libgpg-error0:amd64.shlibs
# var/lib/dpkg/info/mawk.prerm
# var/lib/dpkg/info/libpcre3:amd64.list
# var/lib/dpkg/info/libgnutls30:amd64.symbols
# var/lib/dpkg/info/perl-base.preinst
# var/lib/dpkg/info/libgnutls30:amd64.list
# var/lib/dpkg/info/libidn2-0:amd64.symbols
# var/lib/dpkg/info/apt.md5sums
# var/lib/dpkg/info/base-files.md5sums
# var/lib/dpkg/info/libcrypt1:amd64.shlibs
# var/lib/dpkg/info/libc6:amd64.preinst
# var/lib/dpkg/info/dash.templates
# var/lib/dpkg/info/libdebconfclient0:amd64.shlibs
# var/lib/dpkg/info/util-linux.conffiles
# var/lib/dpkg/info/base-files.postrm
# var/lib/dpkg/info/mount.list
# var/lib/dpkg/info/tar.list
# var/lib/dpkg/info/libpam0g:amd64.postinst
# var/lib/dpkg/info/libmount1:amd64.list
# var/lib/dpkg/info/libpam-modules-bin.list
# var/lib/dpkg/info/libunistring2:amd64.shlibs
# var/lib/dpkg/info/libpam0g:amd64.symbols
# var/lib/dpkg/info/zlib1g:amd64.list
# var/lib/dpkg/info/libudev1:amd64.md5sums
# var/lib/dpkg/info/libfdisk1:amd64.triggers
# var/lib/dpkg/info/libhogweed5:amd64.list
# var/lib/dpkg/info/libmount1:amd64.triggers
# var/lib/dpkg/info/libc6:amd64.conffiles
# var/lib/dpkg/info/util-linux.postrm
# var/lib/dpkg/info/passwd.prerm
# var/lib/dpkg/info/dash.prerm
# var/lib/dpkg/info/libzstd1:amd64.md5sums
# var/lib/dpkg/info/libncursesw6:amd64.triggers
# var/lib/dpkg/info/libstdc++6:amd64.list
# var/lib/dpkg/info/libncursesw6:amd64.list
# var/lib/dpkg/info/sysvinit-utils.list
# var/lib/dpkg/info/lsb-base.list
# var/lib/dpkg/info/libbz2-1.0:amd64.triggers
# var/lib/dpkg/info/dash.postinst
# var/lib/dpkg/info/libncursesw6:amd64.shlibs
# var/lib/dpkg/info/dash.md5sums
# var/lib/dpkg/info/libpam-runtime.templates
# var/lib/dpkg/info/libgmp10:amd64.shlibs
# var/lib/dpkg/info/libgpg-error0:amd64.triggers
# var/lib/dpkg/info/libblkid1:amd64.triggers
# var/lib/dpkg/info/libsystemd0:amd64.shlibs
# var/lib/dpkg/info/libgpg-error0:amd64.md5sums
# var/lib/dpkg/info/libstdc++6:amd64.shlibs
# var/lib/dpkg/info/libaudit-common.md5sums
# var/lib/dpkg/info/libsystemd0:amd64.md5sums
# var/lib/dpkg/info/libss2:amd64.shlibs
# var/lib/dpkg/info/libpam-modules:amd64.conffiles
# var/lib/dpkg/info/logsave.md5sums
# var/lib/dpkg/info/libuuid1:amd64.symbols
# var/lib/dpkg/info/libpam-runtime.list
# var/lib/dpkg/info/libgcc-s1:amd64.symbols
# var/lib/dpkg/info/libncurses6:amd64.symbols
# var/lib/dpkg/info/libselinux1:amd64.list
# var/lib/dpkg/info/libffi7:amd64.shlibs
# var/lib/dpkg/info/libidn2-0:amd64.list
# var/lib/dpkg/info/grep.md5sums
# var/lib/dpkg/info/liblz4-1:amd64.md5sums
# var/lib/dpkg/info/libprocps8:amd64.md5sums
# var/lib/dpkg/info/debconf.conffiles
# var/lib/dpkg/info/libc6:amd64.triggers
# var/lib/dpkg/info/fdisk.list
# var/lib/dpkg/info/libgcc-s1:amd64.md5sums
# var/lib/dpkg/info/ncurses-base.md5sums
# var/lib/dpkg/info/base-files.prerm
# var/lib/dpkg/info/liblz4-1:amd64.shlibs
# var/lib/dpkg/info/debconf.templates
# var/lib/dpkg/info/libpam-modules:amd64.preinst
# var/lib/dpkg/info/dash.list
# var/lib/dpkg/info/diffutils.md5sums
# var/lib/dpkg/info/liblzma5:amd64.list
# var/lib/dpkg/info/util-linux.list
# var/lib/dpkg/info/hostname.md5sums
# var/lib/dpkg/info/gpgv.md5sums
# var/lib/dpkg/info/login.prerm
# var/lib/dpkg/info/libhogweed5:amd64.shlibs
# var/lib/dpkg/info/libcom-err2:amd64.md5sums
# var/lib/dpkg/info/debianutils.list
# var/lib/dpkg/info/debconf.postinst
# var/lib/dpkg/info/libprocps8:amd64.shlibs
# var/lib/dpkg/info/dash.config
# var/lib/dpkg/info/apt.shlibs
# var/lib/dpkg/info/libacl1:amd64.symbols
# var/lib/dpkg/info/libseccomp2:amd64.list
# var/lib/dpkg/info/gzip.list
# var/lib/dpkg/info/bash.list
# var/lib/dpkg/info/libc6:amd64.list
# var/lib/dpkg/info/libmount1:amd64.shlibs
# var/lib/dpkg/info/dpkg.list
# var/lib/dpkg/info/adduser.config
# var/lib/dpkg/info/libsepol1:amd64.md5sums
# var/lib/dpkg/info/diffutils.list
# var/lib/dpkg/info/libapt-pkg6.0:amd64.list
# var/lib/dpkg/info/grep.list
# var/lib/dpkg/info/ncurses-bin.md5sums
# var/lib/dpkg/info/libcap-ng0:amd64.shlibs
# var/lib/dpkg/info/libselinux1:amd64.md5sums
# var/lib/dpkg/info/libselinux1:amd64.triggers
# var/lib/dpkg/info/libgmp10:amd64.triggers
# var/lib/dpkg/info/libsemanage1:amd64.md5sums
# var/lib/dpkg/info/libsepol1:amd64.symbols
# var/lib/dpkg/info/libncurses6:amd64.list
# var/lib/dpkg/info/libpam0g:amd64.md5sums
# var/lib/dpkg/info/libext2fs2:amd64.list
# var/lib/dpkg/info/dpkg.postinst
# var/lib/dpkg/info/libpam0g:amd64.list
# var/lib/dpkg/info/login.preinst
# var/lib/dpkg/info/libpam-modules:amd64.md5sums
# var/lib/dpkg/info/libgmp10:amd64.md5sums
# var/lib/dpkg/info/libnettle7:amd64.symbols
# var/lib/dpkg/info/libc6:amd64.postinst
# var/lib/dpkg/info/liblz4-1:amd64.triggers
# var/lib/dpkg/info/libselinux1:amd64.shlibs
# var/lib/dpkg/info/ubuntu-keyring.list
# var/lib/dpkg/info/libprocps8:amd64.triggers
# var/lib/dpkg/info/zlib1g:amd64.symbols
# var/lib/dpkg/info/init-system-helpers.list
# var/lib/dpkg/info/tar.postinst
# var/lib/dpkg/info/base-passwd.preinst
# var/lib/dpkg/info/libbz2-1.0:amd64.shlibs
# var/lib/dpkg/info/libgcrypt20:amd64.md5sums
# var/lib/dpkg/info/apt.postinst
# var/lib/dpkg/info/libpam-modules:amd64.postrm
# var/lib/dpkg/info/libblkid1:amd64.md5sums
# var/lib/dpkg/info/libapt-pkg6.0:amd64.symbols
# var/lib/dpkg/info/libpcre2-8-0:amd64.md5sums
# var/lib/dpkg/info/mount.md5sums
# var/lib/dpkg/info/libzstd1:amd64.symbols
# var/lib/dpkg/info/apt.postrm
# var/lib/dpkg/info/dpkg.md5sums
# var/lib/dpkg/info/coreutils.postinst
# var/lib/dpkg/info/libcrypt1:amd64.list
# var/lib/dpkg/info/libudev1:amd64.list
# var/lib/dpkg/info/libhogweed5:amd64.symbols
# var/lib/dpkg/info/libtinfo6:amd64.triggers
# var/lib/dpkg/info/procps.preinst
# var/lib/dpkg/info/libfdisk1:amd64.md5sums
# var/lib/dpkg/info/debconf.list
# var/lib/dpkg/info/libfdisk1:amd64.shlibs
# var/lib/dpkg/info/libp11-kit0:amd64.list
# var/lib/dpkg/info/libapt-pkg6.0:amd64.shlibs
# var/lib/dpkg/info/libpcre3:amd64.symbols
# var/lib/dpkg/info/gzip.md5sums
# var/lib/dpkg/info/zlib1g:amd64.shlibs
# var/lib/dpkg/info/libgcc-s1:amd64.list
# var/lib/dpkg/info/libgcrypt20:amd64.triggers
# var/lib/dpkg/info/bash.prerm
# var/lib/dpkg/info/libc6:amd64.shlibs
# var/lib/dpkg/info/debianutils.postinst
# var/lib/dpkg/info/coreutils.postrm
# var/lib/dpkg/info/libcap-ng0:amd64.md5sums
# var/lib/dpkg/info/coreutils.list
# var/lib/dpkg/info/apt.prerm
# var/lib/dpkg/info/adduser.postrm
# var/lib/dpkg/info/libnettle7:amd64.shlibs
# var/lib/dpkg/info/mawk.list
# var/lib/dpkg/info/adduser.list
# var/lib/dpkg/info/libtasn1-6:amd64.md5sums
# var/lib/dpkg/info/libss2:amd64.triggers
# var/lib/dpkg/info/passwd.preinst
# var/lib/dpkg/info/libdebconfclient0:amd64.list
# var/lib/dpkg/info/libseccomp2:amd64.shlibs
# var/lib/dpkg/info/libc6:amd64.symbols
# var/lib/dpkg/info/libaudit-common.conffiles
# var/lib/dpkg/info/dpkg.postrm
# var/lib/dpkg/info/libcrypt1:amd64.md5sums
# var/lib/dpkg/info/libsystemd0:amd64.symbols
# var/lib/dpkg/info/apt.preinst
# var/lib/dpkg/info/findutils.md5sums
# var/lib/dpkg/info/debconf.md5sums
# var/lib/dpkg/info/libunistring2:amd64.list
# var/lib/dpkg/info/libpam-modules:amd64.postinst
# var/lib/dpkg/info/procps.list
# var/lib/dpkg/info/libtasn1-6:amd64.shlibs
# var/lib/dpkg/info/libcom-err2:amd64.shlibs
# var/lib/dpkg/info/gpgv.list
# var/lib/dpkg/info/libsystemd0:amd64.list
# var/lib/dpkg/info/libpcre2-8-0:amd64.shlibs
# var/lib/dpkg/info/libgcc-s1:amd64.triggers
# var/lib/dpkg/info/e2fsprogs.preinst
# var/lib/dpkg/info/passwd.postinst
# var/lib/dpkg/info/perl-base.list
# var/lib/dpkg/info/libaudit1:amd64.shlibs
# var/lib/dpkg/info/libpam-modules:amd64.templates
# var/lib/dpkg/info/apt.list
# var/lib/dpkg/info/libdebconfclient0:amd64.md5sums
# var/lib/dpkg/info/libapt-pkg6.0:amd64.md5sums
# var/lib/dpkg/info/libmount1:amd64.symbols
# var/lib/dpkg/info/libunistring2:amd64.md5sums
# var/lib/dpkg/info/base-files.list
# var/lib/dpkg/info/libsmartcols1:amd64.symbols
# var/lib/dpkg/info/libattr1:amd64.conffiles
# var/lib/dpkg/info/debianutils.postrm
# var/lib/dpkg/info/libsepol1:amd64.list
# var/lib/dpkg/info/libstdc++6:amd64.symbols
# var/lib/dpkg/info/logsave.list
# var/lib/dpkg/info/tar.prerm
# var/lib/dpkg/info/bzip2.md5sums
# var/lib/dpkg/info/e2fsprogs.list
# var/lib/dpkg/info/libgmp10:amd64.symbols
# var/lib/dpkg/info/libzstd1:amd64.list
# var/lib/dpkg/info/libffi7:amd64.md5sums
# var/lib/dpkg/info/debianutils.md5sums
# var/lib/dpkg/info/libsemanage1:amd64.symbols
# var/lib/dpkg/info/libattr1:amd64.list
# var/lib/dpkg/info/libpam0g:amd64.templates
# var/lib/dpkg/info/libp11-kit0:amd64.md5sums
# var/lib/dpkg/info/e2fsprogs.conffiles
# var/lib/dpkg/info/lsb-base.postrm
# var/lib/dpkg/info/libattr1:amd64.triggers
# var/lib/dpkg/info/libpam0g:amd64.postrm
# var/lib/dpkg/info/liblzma5:amd64.symbols
# var/lib/dpkg/info/libsemanage1:amd64.shlibs
# var/lib/dpkg/info/dash.postrm
# var/lib/dpkg/info/sensible-utils.md5sums
# var/lib/dpkg/info/hostname.list
# var/lib/dpkg/info/libidn2-0:amd64.triggers
# var/lib/dpkg/info/libgpg-error0:amd64.symbols
# var/lib/dpkg/info/coreutils.md5sums
# var/lib/dpkg/info/adduser.postinst
# var/lib/dpkg/info/tar.md5sums
# var/lib/dpkg/info/perl-base.prerm
# var/lib/dpkg/info/libext2fs2:amd64.shlibs
# var/lib/dpkg/info/libpcre2-8-0:amd64.triggers
# var/lib/dpkg/info/libss2:amd64.symbols
# var/lib/dpkg/info/libdb5.3:amd64.triggers
# var/lib/dpkg/info/libpam0g:amd64.triggers
# var/lib/dpkg/info/libgcrypt20:amd64.list
# var/lib/dpkg/info/libc-bin.md5sums
# var/lib/dpkg/info/lsb-base.prerm
# var/lib/dpkg/info/libncursesw6:amd64.md5sums
# var/lib/dpkg/info/libblkid1:amd64.list
# var/lib/dpkg/info/libidn2-0:amd64.shlibs
# var/lib/dpkg/info/libgnutls30:amd64.md5sums
# var/lib/dpkg/info/libidn2-0:amd64.md5sums
# var/lib/dpkg/info/libattr1:amd64.symbols
# var/lib/dpkg/info/zlib1g:amd64.triggers
# var/lib/dpkg/info/liblzma5:amd64.md5sums
# var/lib/dpkg/info/bash.conffiles
# var/lib/dpkg/info/sensible-utils.list
# var/lib/dpkg/info/debconf.prerm
# var/lib/dpkg/info/libattr1:amd64.shlibs
# var/lib/dpkg/info/passwd.postrm
# var/lib/dpkg/info/init-system-helpers.md5sums
# var/lib/dpkg/info/libgcrypt20:amd64.symbols
# var/lib/dpkg/info/bsdutils.list
# var/lib/dpkg/info/libpam-runtime.md5sums
# var/lib/dpkg/info/libsepol1:amd64.shlibs
# var/lib/dpkg/info/libpcre3:amd64.triggers
# var/lib/dpkg/info/ncurses-bin.list
# var/lib/dpkg/info/libext2fs2:amd64.symbols
# var/lib/dpkg/info/libext2fs2:amd64.md5sums
# var/lib/dpkg/info/mawk.md5sums
# var/lib/dpkg/info/libext2fs2:amd64.triggers
# var/lib/dpkg/info/libgpg-error0:amd64.list
# var/lib/dpkg/info/libblkid1:amd64.shlibs
# var/lib/dpkg/info/ubuntu-keyring.md5sums
# var/lib/dpkg/info/libc6:amd64.postrm
# var/lib/dpkg/info/libaudit-common.list
# var/lib/dpkg/info/libpcre3:amd64.shlibs
# var/lib/dpkg/info/libtinfo6:amd64.symbols
# var/lib/dpkg/info/liblzma5:amd64.shlibs
# var/lib/dpkg/info/libp11-kit0:amd64.triggers
# var/lib/dpkg/info/libzstd1:amd64.shlibs
# var/lib/dpkg/info/login.postrm
# var/lib/dpkg/info/passwd.conffiles
# var/lib/dpkg/info/e2fsprogs.prerm
# var/lib/dpkg/info/libuuid1:amd64.triggers
# var/lib/dpkg/info/format
# var/lib/dpkg/info/libcom-err2:amd64.list
# var/lib/dpkg/info/libtinfo6:amd64.list
# var/lib/dpkg/info/libaudit1:amd64.symbols
# var/lib/dpkg/info/ncurses-base.list
# var/lib/dpkg/info/libbz2-1.0:amd64.md5sums
# var/lib/dpkg/info/libmount1:amd64.md5sums
# var/lib/dpkg/info/adduser.conffiles
# var/lib/dpkg/info/libpcre3:amd64.md5sums
# var/lib/dpkg/info/libprocps8:amd64.list
# var/lib/dpkg/info/login.list
# var/lib/dpkg/info/sed.md5sums
# var/lib/dpkg/info/adduser.templates
# var/lib/dpkg/info/bash.postinst
# var/lib/dpkg/info/libudev1:amd64.symbols
# var/lib/dpkg/info/libffi7:amd64.triggers
# var/lib/dpkg/info/libss2:amd64.md5sums
# var/lib/dpkg/info/libp11-kit0:amd64.shlibs
# var/lib/dpkg/info/libpam-runtime.postrm
# var/lib/dpkg/info/libhogweed5:amd64.triggers
# var/lib/dpkg/info/lsb-base.preinst
# var/lib/dpkg/info/libdb5.3:amd64.md5sums
# var/lib/dpkg/info/libgcrypt20:amd64.shlibs
# var/lib/dpkg/info/util-linux.postinst
# var/lib/dpkg/info/passwd.list
# var/lib/dpkg/info/libcrypt1:amd64.symbols
# var/lib/dpkg/info/libc-bin.postinst
# var/lib/dpkg/info/libdebconfclient0:amd64.symbols
# var/lib/dpkg/info/gcc-10-base:amd64.md5sums
# var/lib/dpkg/info/dpkg.conffiles
# var/lib/dpkg/info/libc-bin.conffiles
# var/lib/dpkg/info/libncurses6:amd64.md5sums
# var/lib/dpkg/info/libuuid1:amd64.list
# var/lib/dpkg/info/libaudit1:amd64.list
# var/lib/dpkg/info/libunistring2:amd64.triggers
# var/lib/dpkg/info/base-files.postinst
# var/lib/dpkg/info/libsepol1:amd64.triggers
# var/lib/dpkg/info/libaudit1:amd64.triggers
# var/lib/dpkg/info/libffi7:amd64.list
# var/lib/dpkg/info/libsemanage-common.md5sums
# var/lib/dpkg/info/procps.postrm
# var/lib/dpkg/info/e2fsprogs.postinst
# var/lib/dpkg/info/libnettle7:amd64.triggers
# var/lib/dpkg/info/libpam-modules:amd64.list
# var/lib/dpkg/info/libseccomp2:amd64.symbols
# var/lib/dpkg/info/sysvinit-utils.md5sums
# var/lib/dpkg/info/perl-base.md5sums
# var/lib/dpkg/info/passwd.md5sums
# var/lib/dpkg/info/libnettle7:amd64.md5sums
# var/lib/dpkg/info/libncursesw6:amd64.symbols
# var/lib/dpkg/info/libsemanage-common.list
# var/lib/dpkg/info/util-linux.prerm
# var/lib/dpkg/info/lsb-base.postinst
# var/lib/dpkg/info/libsmartcols1:amd64.triggers
# var/lib/dpkg/info/base-passwd.templates
# var/lib/dpkg/info/libacl1:amd64.triggers
# var/lib/dpkg/info/procps.prerm
# var/lib/dpkg/info/libselinux1:amd64.symbols
# var/lib/dpkg/info/libdebconfclient0:amd64.triggers
# var/lib/dpkg/info/libpcre2-8-0:amd64.symbols
# var/lib/dpkg/info/libunistring2:amd64.symbols
# var/lib/dpkg/info/libss2:amd64.list
# var/lib/dpkg/info/fdisk.md5sums
# var/lib/dpkg/info/debconf.config
# var/lib/dpkg/info/sed.list
# var/lib/dpkg/info/libsystemd0:amd64.triggers
# var/lib/dpkg/info/base-files.preinst
# var/lib/dpkg/info/libtinfo6:amd64.shlibs
# var/lib/dpkg/info/ncurses-base.conffiles
# var/lib/dpkg/info/libseccomp2:amd64.triggers
# var/lib/dpkg/info/procps.postinst
# var/lib/dpkg/info/libtasn1-6:amd64.triggers
# var/lib/dpkg/info/apt.triggers
# var/lib/dpkg/info/bsdutils.md5sums
# var/lib/dpkg/info/base-files.conffiles
# var/lib/dpkg/info/bash.preinst
# var/lib/dpkg/info/libncurses6:amd64.triggers
# var/lib/dpkg/info/libuuid1:amd64.md5sums
# var/lib/dpkg/info/libcap-ng0:amd64.symbols
# var/lib/dpkg/info/libffi7:amd64.symbols
# var/lib/dpkg/info/libdb5.3:amd64.list
# var/lib/dpkg/info/libgnutls30:amd64.shlibs
# var/lib/dpkg/info/libdb5.3:amd64.shlibs
# var/lib/dpkg/info/libtasn1-6:amd64.list
# var/lib/dpkg/info/gcc-10-base:amd64.list
# var/lib/dpkg/info/liblz4-1:amd64.symbols
# var/lib/dpkg/info/libstdc++6:amd64.triggers
# var/lib/dpkg/info/libsemanage1:amd64.list
# var/lib/dpkg/info/bash.md5sums
# var/lib/dpkg/info/libacl1:amd64.md5sums
# var/lib/dpkg/info/libcap-ng0:amd64.list
# var/lib/dpkg/info/libbz2-1.0:amd64.list
# var/lib/dpkg/info/login.md5sums
# var/lib/dpkg/info/libc-bin.triggers
# var/lib/dpkg/info/login.postinst
# var/lib/dpkg/info/bash.postrm
# var/lib/dpkg/info/liblzma5:amd64.triggers
# var/lib/dpkg/info/mawk.postinst
# var/lib/dpkg/info/libtinfo6:amd64.md5sums
# var/lib/dpkg/info/libpam-modules-bin.md5sums
# var/lib/dpkg/info/libp11-kit0:amd64.symbols
# var/lib/dpkg/info/libudev1:amd64.shlibs
# var/lib/dpkg/info/libsemanage-common.conffiles
# var/lib/dpkg/info/perl-base.postinst
# var/lib/dpkg/info/base-passwd.md5sums
# var/lib/dpkg/info/libnettle7:amd64.list
# var/lib/dpkg/info/libacl1:amd64.list
# var/lib/dpkg/info/libfdisk1:amd64.symbols
# var/lib/dpkg/info/libpam0g:amd64.shlibs
# var/lib/dpkg/info/libstdc++6:amd64.md5sums
# var/lib/dpkg/info/libc-bin.list
# var/lib/dpkg/info/libstdc++6:amd64.prerm
# var/lib/dpkg/info/libc6:amd64.templates
# var/lib/dpkg/info/base-passwd.list
# var/lib/dpkg/info/ubuntu-keyring.postinst
# var/lib/dpkg/info/e2fsprogs.md5sums
# var/lib/dpkg/info/libsmartcols1:amd64.shlibs
# var/lib/dpkg/info/liblz4-1:amd64.list
# var/lib/dpkg/info/libsmartcols1:amd64.list
# var/lib/dpkg/info/libpam-runtime.conffiles
# var/lib/dpkg/info/debconf.postrm
# var/lib/dpkg/info/findutils.list
# var/lib/dpkg/info/apt.conffiles
# var/lib/dpkg/info/bzip2.list
# var/lib/dpkg/info/libcap-ng0:amd64.triggers
# var/lib/dpkg/info/zlib1g:amd64.md5sums
# var/lib/dpkg/info/libcom-err2:amd64.symbols
# var/lib/dpkg/info/procps.md5sums
# var/lib/dpkg/info/libc6:amd64.md5sums
# var/lib/dpkg/info/libapt-pkg6.0:amd64.triggers
# var/lib/dpkg/info/libhogweed5:amd64.md5sums
# var/lib/dpkg/info/libcom-err2:amd64.triggers
# var/lib/dpkg/info/libsemanage1:amd64.triggers
# var/lib/dpkg/info/libfdisk1:amd64.list
# var/lib/dpkg/info/libgcc-s1:amd64.shlibs
# var/lib/dpkg/info/libpam-runtime.postinst
# var/lib/dpkg/info/libaudit1:amd64.md5sums
# var/lib/dpkg/info/libgmp10:amd64.list
# var/lib/dpkg/info/libsmartcols1:amd64.md5sums
# var/lib/dpkg/info/debconf.preinst
# var/lib/dpkg/info/libgnutls30:amd64.triggers
# var/lib/dpkg/info/procps.conffiles
# var/lib/dpkg/info/base-passwd.postinst
# var/lib/dpkg/info/libacl1:amd64.shlibs
# var/lib/dpkg/info/libudev1:amd64.triggers
# var/lib/dpkg/info/e2fsprogs.postrm
# var/lib/dpkg/info/lsb-base.md5sums
# var/lib/dpkg/info/perl-base.postrm
# var/lib/dpkg/info/r-cran-reprex.list
# var/lib/dpkg/info/r-cran-cellranger.list
# var/lib/dpkg/info/r-cran-sessioninfo.md5sums
# var/lib/dpkg/info/r-cran-yaml.md5sums
# var/lib/dpkg/info/r-cran-isoband.list
# var/lib/dpkg/info/r-cran-hms.md5sums
# var/lib/dpkg/info/r-cran-jquerylib.md5sums
# var/lib/dpkg/info/r-cran-readr.md5sums
# var/lib/dpkg/info/r-cran-fontawesome.md5sums
# var/lib/dpkg/info/r-cran-timechange.md5sums
# var/lib/dpkg/info/r-cran-diffobj.list
# var/lib/dpkg/info/r-cran-prettyunits.md5sums
# var/lib/dpkg/info/r-cran-commonmark.md5sums
# var/lib/dpkg/info/r-cran-highr.list
# var/lib/dpkg/info/r-cran-tidyr.list
# var/lib/dpkg/info/r-cran-stringr.list
# var/lib/dpkg/info/pandoc-data.list
# var/lib/dpkg/info/r-cran-colorspace.md5sums
# var/lib/dpkg/info/r-cran-modelr.list
# var/lib/dpkg/info/r-cran-bit64.md5sums
# var/lib/dpkg/info/r-cran-devtools.list
# var/lib/dpkg/info/r-cran-rmarkdown.md5sums
# var/lib/dpkg/info/r-cran-gitcreds.md5sums
# var/lib/dpkg/info/r-cran-magrittr.md5sums
# var/lib/dpkg/info/r-cran-bslib.md5sums
# var/lib/dpkg/info/r-cran-tzdb.md5sums
# var/lib/dpkg/info/r-cran-haven.list
# var/lib/dpkg/info/r-cran-readxl.md5sums
# var/lib/dpkg/info/r-cran-ellipsis.list
# var/lib/dpkg/info/r-cran-ps.md5sums
# var/lib/dpkg/info/r-cran-data.table.md5sums
# var/lib/dpkg/info/r-cran-tinytex.md5sums
# var/lib/dpkg/info/r-cran-vroom.list
# var/lib/dpkg/info/r-cran-xopen.md5sums
# var/lib/dpkg/info/r-cran-desc.list
# var/lib/dpkg/info/r-cran-whisker.md5sums
# var/lib/dpkg/info/r-cran-systemfonts.md5sums
# var/lib/dpkg/info/r-cran-openssl.md5sums
# var/lib/dpkg/info/r-cran-highr.md5sums
# var/lib/dpkg/info/r-cran-readxl.list
# var/lib/dpkg/info/r-cran-ggplot2.md5sums
# var/lib/dpkg/info/libpng-tools.list
# var/lib/dpkg/info/r-cran-rvest.md5sums
# var/lib/dpkg/info/r-cran-askpass.list
# var/lib/dpkg/info/r-cran-stringi.md5sums
# var/lib/dpkg/info/r-cran-viridislite.md5sums
# var/lib/dpkg/info/r-cran-ellipsis.md5sums
# var/lib/dpkg/info/r-cran-magrittr.list
# var/lib/dpkg/info/r-cran-svglite.md5sums
# var/lib/dpkg/info/r-cran-cpp11.list
# var/lib/dpkg/info/r-cran-clipr.md5sums
# var/lib/dpkg/info/r-cran-gert.md5sums
# var/lib/dpkg/info/r-cran-dplyr.list
# var/lib/dpkg/info/r-cran-yaml.list
# var/lib/dpkg/info/r-cran-httr.md5sums
# var/lib/dpkg/info/r-cran-crayon.list
# var/lib/dpkg/info/xsel.list
# var/lib/dpkg/info/r-cran-utf8.list
# var/lib/dpkg/info/r-cran-selectr.md5sums
# var/lib/dpkg/info/r-cran-rlang.list
# var/lib/dpkg/info/r-cran-svglite.list
# var/lib/dpkg/info/r-cran-viridislite.list
# var/lib/dpkg/info/r-cran-rstudioapi.md5sums
# var/lib/dpkg/info/r-cran-rcmdcheck.md5sums
# var/lib/dpkg/info/r-cran-cpp11.md5sums
# var/lib/dpkg/info/r-cran-pillar.md5sums
# var/lib/dpkg/info/r-cran-tidyverse.md5sums
# var/lib/dpkg/info/r-cran-callr.md5sums
# var/lib/dpkg/info/r-cran-stringi.list
# var/lib/dpkg/info/r-cran-broom.md5sums
# var/lib/dpkg/info/r-cran-withr.list
# var/lib/dpkg/info/r-cran-cachem.list
# var/lib/dpkg/info/r-cran-httr2.md5sums
# var/lib/dpkg/info/r-cran-whisker.list
# var/lib/dpkg/info/r-cran-generics.list
# var/lib/dpkg/info/r-cran-cellranger.md5sums
# var/lib/dpkg/info/r-cran-munsell.list
# var/lib/dpkg/info/r-cran-googlesheets4.list
# var/lib/dpkg/info/r-cran-dbi.md5sums
# var/lib/dpkg/info/r-cran-ids.md5sums
# var/lib/dpkg/info/r-cran-rappdirs.list
# var/lib/dpkg/info/r-cran-tibble.list
# var/lib/dpkg/info/r-cran-broom.list
# var/lib/dpkg/info/r-cran-credentials.list
# var/lib/dpkg/info/r-cran-purrr.md5sums
# var/lib/dpkg/info/r-cran-gtable.list
# var/lib/dpkg/info/r-cran-base64enc.list
# var/lib/dpkg/info/r-cran-zip.md5sums
# var/lib/dpkg/info/r-cran-sys.md5sums
# var/lib/dpkg/info/r-cran-bit64.list
# var/lib/dpkg/info/r-cran-ggplot2.list
# var/lib/dpkg/info/r-cran-zip.list
# var/lib/dpkg/info/r-cran-gtable.md5sums
# var/lib/dpkg/info/r-cran-progress.list
# var/lib/dpkg/info/r-cran-rcolorbrewer.md5sums
# var/lib/dpkg/info/r-cran-roxygen2.list
# var/lib/dpkg/info/r-cran-xml2.list
# var/lib/dpkg/info/r-cran-gargle.md5sums
# var/lib/dpkg/info/r-cran-gh.md5sums
# var/lib/dpkg/info/r-cran-rstudioapi.list
# var/lib/dpkg/info/r-cran-rematch.md5sums
# var/lib/dpkg/info/r-cran-xopen.list
# var/lib/dpkg/info/r-cran-rematch.list
# var/lib/dpkg/info/r-cran-rlang.md5sums
# var/lib/dpkg/info/r-cran-knitr.list
# var/lib/dpkg/info/r-cran-usethis.md5sums
# var/lib/dpkg/info/r-cran-rvest.list
# var/lib/dpkg/info/r-cran-processx.md5sums
# var/lib/dpkg/info/r-cran-openssl.list
# var/lib/dpkg/info/r-cran-processx.list
# var/lib/dpkg/info/r-cran-progress.md5sums
# var/lib/dpkg/info/r-cran-pkgbuild.list
# var/lib/dpkg/info/r-cran-htmltools.list
# var/lib/dpkg/info/r-cran-testthat.list
# var/lib/dpkg/info/r-cran-digest.list
# var/lib/dpkg/info/r-cran-purrr.list
# var/lib/dpkg/info/r-cran-blob.md5sums
# var/lib/dpkg/info/r-cran-tidyselect.list
# var/lib/dpkg/info/r-cran-ini.list
# var/lib/dpkg/info/r-cran-blob.list
# var/lib/dpkg/info/r-cran-memoise.md5sums
# var/lib/dpkg/info/r-cran-devtools.md5sums
# var/lib/dpkg/info/r-cran-rmarkdown.list
# var/lib/dpkg/info/r-cran-remotes.list
# var/lib/dpkg/info/r-cran-httr2.list
# var/lib/dpkg/info/r-cran-rcmdcheck.list
# var/lib/dpkg/info/r-cran-uuid.md5sums
# var/lib/dpkg/info/r-cran-gert.list
# var/lib/dpkg/info/r-cran-prettyunits.list
# var/lib/dpkg/info/r-cran-pkgconfig.md5sums
# var/lib/dpkg/info/r-cran-gh.list
# var/lib/dpkg/info/r-cran-xml2.md5sums
# var/lib/dpkg/info/r-cran-ps.list
# var/lib/dpkg/info/r-cran-curl.list
# var/lib/dpkg/info/r-cran-googlesheets4.md5sums
# var/lib/dpkg/info/r-cran-pkgload.list
# var/lib/dpkg/info/r-cran-ids.list
# var/lib/dpkg/info/r-cran-forcats.md5sums
# var/lib/dpkg/info/r-cran-dbi.list
# var/lib/dpkg/info/r-cran-reprex.md5sums
# var/lib/dpkg/info/r-cran-crayon.md5sums
# var/lib/dpkg/info/r-cran-vctrs.md5sums
# var/lib/dpkg/info/r-cran-googledrive.list
# var/lib/dpkg/info/r-cran-tidyr.md5sums
# var/lib/dpkg/info/r-cran-xfun.list
# var/lib/dpkg/info/r-cran-haven.md5sums
# var/lib/dpkg/info/r-cran-brio.list
# var/lib/dpkg/info/r-cran-ini.md5sums
# var/lib/dpkg/info/r-cran-credentials.md5sums
# var/lib/dpkg/info/r-cran-googledrive.md5sums
# var/lib/dpkg/info/r-cran-praise.list
# var/lib/dpkg/info/r-cran-askpass.md5sums
# var/lib/dpkg/info/r-cran-sys.list
# var/lib/dpkg/info/r-cran-data.table.list
# var/lib/dpkg/info/r-cran-commonmark.list
# var/lib/dpkg/info/r-cran-bit.md5sums
# var/lib/dpkg/info/r-cran-dtplyr.md5sums
# var/lib/dpkg/info/r-cran-jquerylib.list
# var/lib/dpkg/info/r-cran-munsell.md5sums
# var/lib/dpkg/info/r-cran-sass.list
# var/lib/dpkg/info/xsel.md5sums
# var/lib/dpkg/info/r-cran-lifecycle.md5sums
# var/lib/dpkg/info/r-cran-forcats.list
# var/lib/dpkg/info/r-cran-scales.md5sums
# var/lib/dpkg/info/r-cran-fs.list
# var/lib/dpkg/info/r-cran-mime.md5sums
# var/lib/dpkg/info/r-cran-dplyr.md5sums
# var/lib/dpkg/info/r-cran-vroom.md5sums
# var/lib/dpkg/info/r-cran-modelr.md5sums
# var/lib/dpkg/info/r-cran-cli.list
# var/lib/dpkg/info/r-cran-tinytex.list
# var/lib/dpkg/info/r-cran-evaluate.list
# var/lib/dpkg/info/r-cran-gargle.list
# var/lib/dpkg/info/r-cran-clipr.list
# var/lib/dpkg/info/r-cran-digest.md5sums
# var/lib/dpkg/info/r-cran-memoise.list
# var/lib/dpkg/info/r-cran-generics.md5sums
# var/lib/dpkg/info/r-cran-lifecycle.list
# var/lib/dpkg/info/r-cran-utf8.md5sums
# var/lib/dpkg/info/r-cran-waldo.list
# var/lib/dpkg/info/r-cran-sass.md5sums
# var/lib/dpkg/info/r-cran-stringr.md5sums
# var/lib/dpkg/info/libpng-tools.md5sums
# var/lib/dpkg/info/r-cran-lubridate.list
# var/lib/dpkg/info/r-cran-desc.md5sums
# var/lib/dpkg/info/r-cran-praise.md5sums
# var/lib/dpkg/info/r-cran-tidyverse.list
# var/lib/dpkg/info/r-cran-tibble.md5sums
# var/lib/dpkg/info/r-cran-rversions.md5sums
# var/lib/dpkg/info/r-cran-rematch2.md5sums
# var/lib/dpkg/info/r-cran-rprojroot.list
# var/lib/dpkg/info/r-cran-scales.list
# var/lib/dpkg/info/pandoc-data.md5sums
# var/lib/dpkg/info/pandoc.md5sums
# var/lib/dpkg/info/r-cran-timechange.list
# var/lib/dpkg/info/r-cran-roxygen2.md5sums
# var/lib/dpkg/info/r-cran-pkgload.md5sums
# var/lib/dpkg/info/r-cran-rversions.list
# var/lib/dpkg/info/r-cran-rcolorbrewer.list
# var/lib/dpkg/info/r-cran-glue.list
# var/lib/dpkg/info/r-cran-callr.list
# var/lib/dpkg/info/r-cran-bit.list
# var/lib/dpkg/info/r-cran-pkgbuild.md5sums
# var/lib/dpkg/info/r-cran-labeling.list
# var/lib/dpkg/info/r-cran-fansi.list
# var/lib/dpkg/info/r-cran-base64enc.md5sums
# var/lib/dpkg/info/r-cran-httr.list
# var/lib/dpkg/info/r-cran-labeling.md5sums
# var/lib/dpkg/info/r-cran-isoband.md5sums
# var/lib/dpkg/info/r-cran-withr.md5sums
# var/lib/dpkg/info/r-cran-rematch2.list
# var/lib/dpkg/info/r-cran-knitr.md5sums
# var/lib/dpkg/info/r-cran-dbplyr.list
# var/lib/dpkg/info/r-cran-testthat.md5sums
# var/lib/dpkg/info/r-cran-evaluate.md5sums
# var/lib/dpkg/info/r-cran-glue.md5sums
# var/lib/dpkg/info/r-cran-vctrs.list
# var/lib/dpkg/info/pandoc.list
# var/lib/dpkg/info/r-cran-dtplyr.list
# var/lib/dpkg/info/r-cran-fansi.md5sums
# var/lib/dpkg/info/r-cran-systemfonts.list
# var/lib/dpkg/info/r-cran-rprojroot.md5sums
# var/lib/dpkg/info/r-cran-tidyselect.md5sums
# var/lib/dpkg/info/r-cran-farver.md5sums
# var/lib/dpkg/info/r-cran-uuid.list
# var/lib/dpkg/info/r-cran-cli.md5sums
# var/lib/dpkg/info/r-cran-pillar.list
# var/lib/dpkg/info/r-cran-brio.md5sums
# var/lib/dpkg/info/r-cran-waldo.md5sums
# var/lib/dpkg/info/r-cran-brew.md5sums
# var/lib/dpkg/info/r-cran-dbplyr.md5sums
# var/lib/dpkg/info/r-cran-htmltools.md5sums
# var/lib/dpkg/info/r-cran-fastmap.md5sums
# var/lib/dpkg/info/r-cran-backports.list
# var/lib/dpkg/info/r-cran-farver.list
# var/lib/dpkg/info/r-cran-brew.list
# var/lib/dpkg/info/r-cran-readr.list
# var/lib/dpkg/info/r-cran-jsonlite.list
# var/lib/dpkg/info/r-cran-hms.list
# var/lib/dpkg/info/r-cran-lubridate.md5sums
# var/lib/dpkg/info/r-cran-fastmap.list
# var/lib/dpkg/info/r-cran-xfun.md5sums
# var/lib/dpkg/info/r-cran-backports.md5sums
# var/lib/dpkg/info/r-cran-jsonlite.md5sums
# var/lib/dpkg/info/r-cran-pkgconfig.list
# var/lib/dpkg/info/r-cran-mime.list
# var/lib/dpkg/info/r-cran-gitcreds.list
# var/lib/dpkg/info/r-cran-diffobj.md5sums
# var/lib/dpkg/info/r-cran-r6.md5sums
# var/lib/dpkg/info/r-cran-r6.list
# var/lib/dpkg/info/r-cran-fontawesome.list
# var/lib/dpkg/info/r-cran-remotes.md5sums
# var/lib/dpkg/info/r-cran-colorspace.list
# var/lib/dpkg/info/r-cran-sessioninfo.list
# var/lib/dpkg/info/r-cran-fs.md5sums
# var/lib/dpkg/info/r-cran-curl.md5sums
# var/lib/dpkg/info/r-cran-cachem.md5sums
# var/lib/dpkg/info/r-cran-usethis.list
# var/lib/dpkg/info/r-cran-rappdirs.md5sums
# var/lib/dpkg/info/r-cran-tzdb.list
# var/lib/dpkg/info/r-cran-bslib.list
# var/lib/dpkg/info/r-cran-selectr.list
# var/lib/dpkg/info/libbsd0:amd64.shlibs
# var/lib/dpkg/info/git.postrm
# var/lib/dpkg/info/libgdk-pixbuf2.0-0:amd64.symbols
# var/lib/dpkg/info/python3-dbus.list
# var/lib/dpkg/info/libgcrypt20-dev.list
# var/lib/dpkg/info/libavutil56:amd64.symbols
# var/lib/dpkg/info/libgl1-mesa-dri:amd64.preinst
# var/lib/dpkg/info/libnss3:amd64.md5sums
# var/lib/dpkg/info/libtimedate-perl.list
# var/lib/dpkg/info/libwrap0:amd64.postrm
# var/lib/dpkg/info/libkmlconvenience1:amd64.triggers
# var/lib/dpkg/info/libopencv-objdetect4.2:amd64.shlibs
# var/lib/dpkg/info/libinput10:amd64.md5sums
# var/lib/dpkg/info/unzip.postinst
# var/lib/dpkg/info/libtwolame0:amd64.md5sums
# var/lib/dpkg/info/libgstreamer-plugins-base1.0-0:amd64.shlibs
# var/lib/dpkg/info/libboost-graph-dev:amd64.md5sums
# var/lib/dpkg/info/dbus.triggers
# var/lib/dpkg/info/libboost-context1.71.0:amd64.shlibs
# var/lib/dpkg/info/libopencv-viz-dev:amd64.list
# var/lib/dpkg/info/libfreetype6-dev:amd64.postrm
# var/lib/dpkg/info/libpsm2-2.md5sums
# var/lib/dpkg/info/libxcb-render0:amd64.triggers
# var/lib/dpkg/info/libssl-dev:amd64.md5sums
# var/lib/dpkg/info/libopencv-features2d4.2:amd64.md5sums
# var/lib/dpkg/info/libpng16-16:amd64.shlibs
# var/lib/dpkg/info/libasound2:amd64.md5sums
# var/lib/dpkg/info/libgdal29.md5sums
# var/lib/dpkg/info/libpulse0:amd64.symbols
# var/lib/dpkg/info/nvidia-opencl-dev:amd64.md5sums
# var/lib/dpkg/info/libboost-container1.71.0:amd64.list
# var/lib/dpkg/info/libopenmpi-dev:amd64.postinst
# var/lib/dpkg/info/libgfrpc0:amd64.list
# var/lib/dpkg/info/automake.postinst
# var/lib/dpkg/info/libevent-extra-2.1-7:amd64.symbols
# var/lib/dpkg/info/libunwind8:amd64.md5sums
# var/lib/dpkg/info/libqt5gui5:amd64.prerm
# var/lib/dpkg/info/libpangocairo-1.0-0:amd64.symbols
# var/lib/dpkg/info/manpages.md5sums
# var/lib/dpkg/info/libevent-extra-2.1-7:amd64.md5sums
# var/lib/dpkg/info/openmpi-bin.conffiles
# var/lib/dpkg/info/libapt-pkg-dev:amd64.md5sums
# var/lib/dpkg/info/comerr-dev:amd64.postrm
# var/lib/dpkg/info/libboost-mpi-python1.71.0.postinst
# var/lib/dpkg/info/libpangocairo-1.0-0:amd64.md5sums
# var/lib/dpkg/info/pkg-config.md5sums
# var/lib/dpkg/info/libvdpau1:amd64.triggers
# var/lib/dpkg/info/libavahi-common-data:amd64.list
# var/lib/dpkg/info/libfftw3-double3:amd64.list
# var/lib/dpkg/info/libkmlbase1:amd64.shlibs
# var/lib/dpkg/info/x11proto-scrnsaver-dev.list
# var/lib/dpkg/info/libevent-extra-2.1-7:amd64.shlibs
# var/lib/dpkg/info/libzmq3-dev:amd64.md5sums
# var/lib/dpkg/info/libkmldom1:amd64.shlibs
# var/lib/dpkg/info/tzdata.templates
# var/lib/dpkg/info/libopencv-video-dev:amd64.md5sums
# var/lib/dpkg/info/libboost-coroutine1.71.0:amd64.list
# var/lib/dpkg/info/libgsm1:amd64.md5sums
# var/lib/dpkg/info/libclang1-10.md5sums
# var/lib/dpkg/info/libasound2:amd64.list
# var/lib/dpkg/info/libglib2.0-0:amd64.list
# var/lib/dpkg/info/libuchardet0:amd64.triggers
# var/lib/dpkg/info/libudunits2-dev:amd64.md5sums
# var/lib/dpkg/info/libboost-python-dev.md5sums
# var/lib/dpkg/info/libapparmor1:amd64.symbols
# var/lib/dpkg/info/libopencv-video4.2:amd64.md5sums
# var/lib/dpkg/info/libxcb-xfixes0:amd64.symbols
# var/lib/dpkg/info/libxmuu1:amd64.list
# var/lib/dpkg/info/libsnappy1v5:amd64.triggers
# var/lib/dpkg/info/libibverbs1:amd64.md5sums
# var/lib/dpkg/info/libvulkan1:amd64.md5sums
# var/lib/dpkg/info/libaom0:amd64.shlibs
# var/lib/dpkg/info/libkrb5support0:amd64.triggers
# var/lib/dpkg/info/libboost-date-time1.71.0:amd64.md5sums
# var/lib/dpkg/info/libasound2:amd64.triggers
# var/lib/dpkg/info/libasyncns0:amd64.md5sums
# var/lib/dpkg/info/libkdb5-9:amd64.triggers
# var/lib/dpkg/info/libann0.list
# var/lib/dpkg/info/python3.list
# var/lib/dpkg/info/libxcb-image0:amd64.symbols
# var/lib/dpkg/info/python3-dbus.prerm
# var/lib/dpkg/info/linux-headers-5.4.0-150.md5sums
# var/lib/dpkg/info/libpostproc55:amd64.symbols
# var/lib/dpkg/info/libkadm5srv-mit11:amd64.list
# var/lib/dpkg/info/libtbb-dev:amd64.list
# var/lib/dpkg/info/libfreexl1:amd64.shlibs
# var/lib/dpkg/info/libboost-filesystem1.71.0:amd64.md5sums
# var/lib/dpkg/info/libogg0:amd64.triggers
# var/lib/dpkg/info/libcodec2-0.9:amd64.triggers
# var/lib/dpkg/info/libtime-duration-perl.md5sums
# var/lib/dpkg/info/libfreexl-dev:amd64.md5sums
# var/lib/dpkg/info/libboost-wave1.71.0:amd64.md5sums
# var/lib/dpkg/info/libboost-filesystem1.71.0:amd64.list
# var/lib/dpkg/info/libchromaprint1:amd64.md5sums
# var/lib/dpkg/info/r-cran-codetools.md5sums
# var/lib/dpkg/info/python3.8.postinst
# var/lib/dpkg/info/libspeex1:amd64.list
# var/lib/dpkg/info/libpython3-dev:amd64.md5sums
# var/lib/dpkg/info/libopenal1:amd64.symbols
# var/lib/dpkg/info/python3-software-properties.list
# var/lib/dpkg/info/opencl-c-headers.md5sums
# var/lib/dpkg/info/libpython3.8-minimal:amd64.list
# var/lib/dpkg/info/libjbig-dev:amd64.md5sums
# var/lib/dpkg/info/libpcre2-16-0:amd64.triggers
# var/lib/dpkg/info/libgssrpc4:amd64.md5sums
# var/lib/dpkg/info/libpango-1.0-0:amd64.shlibs
# var/lib/dpkg/info/libgit2-dev:amd64.md5sums
# var/lib/dpkg/info/libboost-iostreams-dev:amd64.list
# var/lib/dpkg/info/libcdio18:amd64.symbols
# var/lib/dpkg/info/libargon2-1:amd64.md5sums
# var/lib/dpkg/info/libglx-dev:amd64.md5sums
# var/lib/dpkg/info/libepoxy0:amd64.md5sums
# var/lib/dpkg/info/libpcre2-32-0:amd64.triggers
# var/lib/dpkg/info/liblab-gamut1:amd64.md5sums
# var/lib/dpkg/info/libvorbis0a:amd64.md5sums
# var/lib/dpkg/info/p7zip-full.list
# var/lib/dpkg/info/libopencv-calib3d-dev:amd64.list
# var/lib/dpkg/info/libvdpau1:amd64.conffiles
# var/lib/dpkg/info/libflac-dev:amd64.list
# var/lib/dpkg/info/libegl1:amd64.triggers
# var/lib/dpkg/info/libssh2-1:amd64.triggers
# var/lib/dpkg/info/python3.8-minimal.prerm
# var/lib/dpkg/info/libasound2-dev:amd64.list
# var/lib/dpkg/info/python3.8-minimal.postrm
# var/lib/dpkg/info/libpcre2-32-0:amd64.list
# var/lib/dpkg/info/libgvpr2:amd64.shlibs
# var/lib/dpkg/info/libpython3-dev:amd64.list
# var/lib/dpkg/info/libavresample4:amd64.md5sums
# var/lib/dpkg/info/libssh-gcrypt-4:amd64.shlibs
# var/lib/dpkg/info/libhdf5-dev.md5sums
# var/lib/dpkg/info/libatk1.0-0:amd64.shlibs
# var/lib/dpkg/info/libboost-regex1.71.0:amd64.list
# var/lib/dpkg/info/python3-minimal.list
# var/lib/dpkg/info/libxcb-icccm4:amd64.shlibs
# var/lib/dpkg/info/libfuse2:amd64.shlibs
# var/lib/dpkg/info/libpcre3-dev:amd64.list
# var/lib/dpkg/info/libgdal29.symbols
# var/lib/dpkg/info/libmnl0:amd64.md5sums
# var/lib/dpkg/info/libgc1c2:amd64.symbols
# var/lib/dpkg/info/gir1.2-glib-2.0:amd64.list
# var/lib/dpkg/info/humanity-icon-theme.postrm
# var/lib/dpkg/info/libboost-filesystem1.71.0:amd64.shlibs
# var/lib/dpkg/info/libcbor0.6:amd64.shlibs
# var/lib/dpkg/info/libpolkit-agent-1-0:amd64.symbols
# var/lib/dpkg/info/libaio1:amd64.symbols
# var/lib/dpkg/info/lsb-release.md5sums
# var/lib/dpkg/info/libodbc1:amd64.triggers
# var/lib/dpkg/info/libboost-serialization1.71.0:amd64.triggers
# var/lib/dpkg/info/libnorm1:amd64.shlibs
# var/lib/dpkg/info/libnl-3-200:amd64.shlibs
# var/lib/dpkg/info/libopencv-contrib4.2:amd64.md5sums
# var/lib/dpkg/info/qtbase5-dev:amd64.md5sums
# var/lib/dpkg/info/libxshmfence1:amd64.list
# var/lib/dpkg/info/libhttp-parser-dev.list
# var/lib/dpkg/info/libssh2-1:amd64.symbols
# var/lib/dpkg/info/libdouble-conversion3:amd64.symbols
# var/lib/dpkg/info/libevdev2:amd64.symbols
# var/lib/dpkg/info/libnl-3-dev:amd64.md5sums
# var/lib/dpkg/info/libboost-program-options1.71.0:amd64.shlibs
# var/lib/dpkg/info/libgvc6.postinst
# var/lib/dpkg/info/libsm6:amd64.md5sums
# var/lib/dpkg/info/libheif-dev:amd64.md5sums
# var/lib/dpkg/info/libdrm-intel1:amd64.shlibs
# var/lib/dpkg/info/libglx0:amd64.list
# var/lib/dpkg/info/libthai0:amd64.shlibs
# var/lib/dpkg/info/libpcre2-32-0:amd64.shlibs
# var/lib/dpkg/info/libpcrecpp0v5:amd64.triggers
# var/lib/dpkg/info/libtirpc-common.conffiles
# var/lib/dpkg/info/policykit-1.preinst
# var/lib/dpkg/info/libsocket++1:amd64.list
# var/lib/dpkg/info/libmagic-mgc.md5sums
# var/lib/dpkg/info/tk8.6.postrm
# var/lib/dpkg/info/libmbedtls-dev:amd64.list
# var/lib/dpkg/info/libogdi4.1.triggers
# var/lib/dpkg/info/libboost-serialization-dev:amd64.list
# var/lib/dpkg/info/proj-data.md5sums
# var/lib/dpkg/info/libdeflate0.symbols
# var/lib/dpkg/info/libsndfile1:amd64.list
# var/lib/dpkg/info/libharfbuzz0b:amd64.list
# var/lib/dpkg/info/libopencv-photo4.2:amd64.triggers
# var/lib/dpkg/info/libavutil56:amd64.md5sums
# var/lib/dpkg/info/libboost-atomic1.71-dev:amd64.list
# var/lib/dpkg/info/libqt5core5a:amd64.triggers
# var/lib/dpkg/info/fio.md5sums
# var/lib/dpkg/info/libkmlbase1:amd64.md5sums
# var/lib/dpkg/info/libpoppler-dev:amd64.md5sums
# var/lib/dpkg/info/libproxy1v5:amd64.shlibs
# var/lib/dpkg/info/libncurses5-dev:amd64.md5sums
# var/lib/dpkg/info/libboost-math1.71-dev:amd64.md5sums
# var/lib/dpkg/info/locales.config
# var/lib/dpkg/info/libprotoc17:amd64.md5sums
# var/lib/dpkg/info/libhdf5-103:amd64.triggers
# var/lib/dpkg/info/libgif-dev.list
# var/lib/dpkg/info/libpathplan4:amd64.list
# var/lib/dpkg/info/mime-support.md5sums
# var/lib/dpkg/info/python3-requests.md5sums
# var/lib/dpkg/info/r-recommended.list
# var/lib/dpkg/info/libgudev-1.0-0:amd64.md5sums
# var/lib/dpkg/info/libxcb-util1:amd64.md5sums
# var/lib/dpkg/info/python3-urllib3.prerm
# var/lib/dpkg/info/libgme0:amd64.triggers
# var/lib/dpkg/info/libopencv-contrib-dev:amd64.list
# var/lib/dpkg/info/libthai-data.md5sums
# var/lib/dpkg/info/libraw1394-11:amd64.shlibs
# var/lib/dpkg/info/libboost-context-dev:amd64.md5sums
# var/lib/dpkg/info/libglapi-mesa:amd64.shlibs
# var/lib/dpkg/info/libxext6:amd64.shlibs
# var/lib/dpkg/info/libass9:amd64.symbols
# var/lib/dpkg/info/zip.list
# var/lib/dpkg/info/lib32gcc-s1.triggers
# var/lib/dpkg/info/libssl1.1:amd64.list
# var/lib/dpkg/info/manpages-posix-dev.list
# var/lib/dpkg/info/libminizip1:amd64.triggers
# var/lib/dpkg/info/libcairo2:amd64.list
# var/lib/dpkg/info/libqt5gui5:amd64.md5sums
# var/lib/dpkg/info/libgstreamer-plugins-base1.0-0:amd64.symbols
# var/lib/dpkg/info/libgts-0.7-5:amd64.list
# var/lib/dpkg/info/python3.10-minimal.preinst
# var/lib/dpkg/info/libpng16-16:amd64.list
# var/lib/dpkg/info/ca-certificates.list
# var/lib/dpkg/info/libopencv-shape4.2:amd64.triggers
# var/lib/dpkg/info/libgif7:amd64.md5sums
# var/lib/dpkg/info/libnl-3-200:amd64.md5sums
# var/lib/dpkg/info/shared-mime-info.md5sums
# var/lib/dpkg/info/ibverbs-providers:amd64.postinst
# var/lib/dpkg/info/libice6:amd64.triggers
# var/lib/dpkg/info/libkadm5clnt-mit11:amd64.shlibs
# var/lib/dpkg/info/libcairo-gobject2:amd64.list
# var/lib/dpkg/info/libopencv-imgproc-dev:amd64.md5sums
# var/lib/dpkg/info/python3.10.postinst
# var/lib/dpkg/info/libboost-all-dev.list
# var/lib/dpkg/info/libkdb5-9:amd64.md5sums
# var/lib/dpkg/info/libssh-4:amd64.symbols
# var/lib/dpkg/info/libxcb-util1:amd64.symbols
# var/lib/dpkg/info/libqt5test5:amd64.list
# var/lib/dpkg/info/libboost-context1.71.0:amd64.triggers
# var/lib/dpkg/info/libkdb5-9:amd64.shlibs
# var/lib/dpkg/info/dbus-user-session.conffiles
# var/lib/dpkg/info/libtesseract4:amd64.triggers
# var/lib/dpkg/info/libjson-c-dev:amd64.md5sums
# var/lib/dpkg/info/libjson-c4:amd64.md5sums
# var/lib/dpkg/info/libgbm1:amd64.shlibs
# var/lib/dpkg/info/less.preinst
# var/lib/dpkg/info/libopencv-dev.list
# var/lib/dpkg/info/libkmod2:amd64.symbols
# var/lib/dpkg/info/libsm-dev:amd64.md5sums
# var/lib/dpkg/info/libcdio-paranoia2:amd64.md5sums
# var/lib/dpkg/info/libpathplan4:amd64.md5sums
# var/lib/dpkg/info/libfabric1.symbols
# var/lib/dpkg/info/odbcinst.conffiles
# var/lib/dpkg/info/libmagic-mgc.list
# var/lib/dpkg/info/shared-mime-info.postrm
# var/lib/dpkg/info/groff-base.md5sums
# var/lib/dpkg/info/locales.postinst
# var/lib/dpkg/info/libboost-graph-parallel1.71.0.triggers
# var/lib/dpkg/info/mime-support.list
# var/lib/dpkg/info/libopencv-dnn4.2:amd64.shlibs
# var/lib/dpkg/info/libwebp-dev:amd64.list
# var/lib/dpkg/info/libboost-numpy-dev.md5sums
# var/lib/dpkg/info/libswscale5:amd64.symbols
# var/lib/dpkg/info/libblocksruntime0.md5sums
# var/lib/dpkg/info/libcdio-cdda2:amd64.shlibs
# var/lib/dpkg/info/libmtdev1:amd64.triggers
# var/lib/dpkg/info/libssh2-1-dev:amd64.md5sums
# var/lib/dpkg/info/distro-info-data.list
# var/lib/dpkg/info/libxfixes3:amd64.symbols
# var/lib/dpkg/info/vim.postinst
# var/lib/dpkg/info/mpi-default-dev.md5sums
# var/lib/dpkg/info/libqt5xml5:amd64.list
# var/lib/dpkg/info/libdrm-intel1:amd64.triggers
# var/lib/dpkg/info/libxinerama1:amd64.list
# var/lib/dpkg/info/libfreexl1:amd64.symbols
# var/lib/dpkg/info/libxcb1:amd64.md5sums
# ...
# var/lib/dpkg/info/libroken18-heimdal:amd64.md5sums
# var/lib/dpkg/info/libasn1-8-heimdal:amd64.triggers
# var/lib/dpkg/info/libroken18-heimdal:amd64.shlibs
# var/lib/dpkg/info/gpg-agent.conffiles
# var/lib/dpkg/info/libgssapi3-heimdal:amd64.symbols
# var/lib/dpkg/info/gpgsm.list
# var/lib/dpkg/info/dirmngr.postrm
# var/lib/dpkg/info/libheimntlm0-heimdal:amd64.md5sums
# var/lib/dpkg/info/dirmngr.preinst
# var/lib/dpkg/info/libsasl2-2:amd64.triggers
# var/lib/dpkg/info/libsasl2-modules-db:amd64.md5sums
# var/lib/dpkg/info/libasn1-8-heimdal:amd64.shlibs
# var/lib/dpkg/info/gpg-wks-client.md5sums
# var/lib/dpkg/info/libksba8:amd64.symbols
# var/lib/dpkg/info/libgssapi3-heimdal:amd64.list
# var/lib/dpkg/info/gnupg-l10n.md5sums
# var/lib/dpkg/info/readline-common.postinst
# var/lib/dpkg/info/gnupg-utils.list
# var/lib/dpkg/info/libsasl2-2:amd64.list
# var/lib/dpkg/info/libkrb5-26-heimdal:amd64.list
# var/lib/dpkg/info/gpg-agent.postrm
# var/lib/dpkg/info/readline-common.md5sums
# var/lib/dpkg/info/libnpth0:amd64.md5sums
# var/lib/dpkg/info/libsqlite3-0:amd64.list
# var/lib/dpkg/info/libksba8:amd64.shlibs
# var/lib/dpkg/info/libroken18-heimdal:amd64.list
# var/lib/dpkg/info/libnpth0:amd64.list
# var/lib/dpkg/info/gpgsm.md5sums
# var/lib/dpkg/info/libgssapi3-heimdal:amd64.shlibs
# var/lib/dpkg/info/libheimbase1-heimdal:amd64.symbols
# var/lib/dpkg/info/libwind0-heimdal:amd64.list
# var/lib/dpkg/info/libassuan0:amd64.shlibs
# var/lib/dpkg/info/libheimntlm0-heimdal:amd64.symbols
# var/lib/dpkg/info/libldap-2.4-2:amd64.triggers
# var/lib/dpkg/info/gpg-agent.md5sums
# var/lib/dpkg/info/libassuan0:amd64.md5sums
# var/lib/dpkg/info/libreadline8:amd64.list
# var/lib/dpkg/info/libldap-common.conffiles
# var/lib/dpkg/info/libheimntlm0-heimdal:amd64.triggers
# var/lib/dpkg/info/gnupg-utils.md5sums
# var/lib/dpkg/info/libhx509-5-heimdal:amd64.symbols
# var/lib/dpkg/info/gpg.md5sums
# var/lib/dpkg/info/libsqlite3-0:amd64.md5sums
# var/lib/dpkg/info/gnupg2.md5sums
# var/lib/dpkg/info/libheimntlm0-heimdal:amd64.list
# var/lib/dpkg/info/openssl.postinst
# var/lib/dpkg/info/libldap-2.4-2:amd64.list
# var/lib/dpkg/info/libkrb5-26-heimdal:amd64.triggers
# var/lib/dpkg/info/libhx509-5-heimdal:amd64.triggers
# var/lib/dpkg/info/libldap-2.4-2:amd64.md5sums
# var/lib/dpkg/info/libhx509-5-heimdal:amd64.shlibs
# var/lib/dpkg/info/dirmngr.list
# var/lib/dpkg/info/libhcrypto4-heimdal:amd64.triggers
# var/lib/dpkg/info/libheimbase1-heimdal:amd64.triggers
# var/lib/dpkg/info/libassuan0:amd64.triggers
# var/lib/dpkg/info/libnpth0:amd64.shlibs
# var/lib/dpkg/info/gpgconf.list
# var/lib/dpkg/info/pinentry-curses.md5sums
# var/lib/dpkg/info/libroken18-heimdal:amd64.triggers
# var/lib/dpkg/info/libwind0-heimdal:amd64.triggers
# var/lib/dpkg/info/gpg-wks-server.md5sums
# var/lib/dpkg/info/libsasl2-2:amd64.shlibs
# var/lib/dpkg/info/libassuan0:amd64.list
# var/lib/dpkg/info/libsasl2-modules-db:amd64.list
# var/lib/dpkg/info/dirmngr.prerm
# var/lib/dpkg/info/libkrb5-26-heimdal:amd64.md5sums
# var/lib/dpkg/info/libldap-common.list
# var/lib/dpkg/info/libkrb5-26-heimdal:amd64.symbols
# var/lib/dpkg/info/dirmngr.postinst
# var/lib/dpkg/info/gpgconf.md5sums
# var/lib/dpkg/info/libwind0-heimdal:amd64.symbols
# var/lib/dpkg/info/libsqlite3-0:amd64.shlibs
# var/lib/dpkg/info/dirmngr.md5sums
# var/lib/dpkg/info/libnpth0:amd64.symbols
# var/lib/dpkg/info/libksba8:amd64.md5sums
# var/lib/dpkg/info/libhcrypto4-heimdal:amd64.symbols
# var/lib/dpkg/info/libheimntlm0-heimdal:amd64.shlibs
# var/lib/dpkg/info/libldap-2.4-2:amd64.symbols
# var/lib/dpkg/info/gpg.list
# var/lib/dpkg/info/libwind0-heimdal:amd64.shlibs
# var/lib/dpkg/info/libasn1-8-heimdal:amd64.md5sums
# var/lib/dpkg/info/readline-common.postrm
# var/lib/dpkg/info/libhcrypto4-heimdal:amd64.shlibs
# var/lib/dpkg/info/libkrb5-26-heimdal:amd64.shlibs
# var/lib/dpkg/info/libsqlite3-0:amd64.symbols
# var/lib/dpkg/info/gnupg-l10n.list
# var/lib/dpkg/info/openssl.conffiles
# var/lib/dpkg/info/gpg-wks-server.list
# var/lib/dpkg/info/gnupg.list
# var/lib/dpkg/info/libldap-2.4-2:amd64.shlibs
# var/lib/dpkg/info/libheimbase1-heimdal:amd64.shlibs
# var/lib/dpkg/info/libsasl2-2:amd64.md5sums
# var/lib/dpkg/info/libreadline8:amd64.symbols
# var/lib/dpkg/info/openssl.md5sums
# var/lib/dpkg/info/gnupg.md5sums
# var/lib/dpkg/status
# var/lib/dpkg/parts/
# var/lib/dpkg/cmethopt
# var/lib/dpkg/updates/
# var/lib/dpkg/lock
# var/lib/dpkg/triggers/
# var/lib/dpkg/triggers/Unincorp
# var/lib/dpkg/triggers/Lock
# var/lib/dpkg/triggers/ldconfig
# var/lib/dpkg/triggers/update-ca-certificates-fresh
# var/lib/dpkg/triggers/File
# var/lib/dpkg/triggers/update-ca-certificates
# var/lib/dpkg/available
# var/lib/dpkg/status-old
# var/lib/dpkg/diversions-old
# var/lib/dpkg/statoverride-old
# var/lib/systemd/
# var/lib/systemd/deb-systemd-helper-enabled/
# var/lib/systemd/deb-systemd-helper-enabled/e2scrub_reap.service.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/
# var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/apt-daily-upgrade.timer
# var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/apt-daily.timer
# var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/fstrim.timer
# var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/e2scrub_all.timer
# var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/motd-news.timer
# var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/man-db.timer
# var/lib/systemd/deb-systemd-helper-enabled/default.target.wants/
# var/lib/systemd/deb-systemd-helper-enabled/default.target.wants/e2scrub_reap.service
# var/lib/systemd/deb-systemd-helper-enabled/e2scrub_all.timer.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/apt-daily.timer.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/fstrim.timer.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/apt-daily-upgrade.timer.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/motd-news.timer.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/dbus-org.freedesktop.timesync1.service
# var/lib/systemd/deb-systemd-helper-enabled/multi-user.target.wants/
# var/lib/systemd/deb-systemd-helper-enabled/multi-user.target.wants/rsync.service
# var/lib/systemd/deb-systemd-helper-enabled/man-db.timer.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/fio.service.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/rsync.service.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/systemd-timesyncd.service.dsh-also
# var/lib/systemd/deb-systemd-helper-enabled/sysinit.target.wants/
# var/lib/systemd/deb-systemd-helper-enabled/sysinit.target.wants/systemd-timesyncd.service
# var/lib/systemd/deb-systemd-user-helper-enabled/
# var/lib/systemd/deb-systemd-user-helper-enabled/gpg-agent-browser.socket.dsh-also
# var/lib/systemd/deb-systemd-user-helper-enabled/gpg-agent-extra.socket.dsh-also
# var/lib/systemd/deb-systemd-user-helper-enabled/sockets.target.wants/
# var/lib/systemd/deb-systemd-user-helper-enabled/sockets.target.wants/gpg-agent.socket
# var/lib/systemd/deb-systemd-user-helper-enabled/sockets.target.wants/gpg-agent-ssh.socket
# var/lib/systemd/deb-systemd-user-helper-enabled/sockets.target.wants/gpg-agent-browser.socket
# var/lib/systemd/deb-systemd-user-helper-enabled/sockets.target.wants/gpg-agent-extra.socket
# var/lib/systemd/deb-systemd-user-helper-enabled/sockets.target.wants/dirmngr.socket
# var/lib/systemd/deb-systemd-user-helper-enabled/sockets.target.wants/pk-debconf-helper.socket
# var/lib/systemd/deb-systemd-user-helper-enabled/gpg-agent-ssh.socket.dsh-also
# var/lib/systemd/deb-systemd-user-helper-enabled/gpg-agent.socket.dsh-also
# var/lib/systemd/deb-systemd-user-helper-enabled/dirmngr.socket.dsh-also
# var/lib/systemd/deb-systemd-user-helper-enabled/pk-debconf-helper.socket.dsh-also
# var/lib/systemd/catalog/
# var/lib/systemd/catalog/database
# var/lib/systemd/coredump/
# var/lib/pam/
# var/lib/pam/account
# var/lib/pam/seen
# var/lib/pam/session-noninteractive
# var/lib/pam/auth
# var/lib/pam/password
# var/lib/pam/session
# var/lib/private/
# var/lib/sudo/
# var/lib/sudo/lectured/
# var/lib/polkit-1/
# var/lib/polkit-1/localauthority/
# var/lib/polkit-1/localauthority/30-site.d/
# var/lib/polkit-1/localauthority/10-vendor.d/
# var/lib/polkit-1/localauthority/10-vendor.d/systemd-networkd.pkla
# var/lib/polkit-1/localauthority/10-vendor.d/org.freedesktop.packagekit.pkla
# var/lib/polkit-1/localauthority/20-org.d/
# var/lib/polkit-1/localauthority/90-mandatory.d/
# var/lib/polkit-1/localauthority/50-local.d/
# var/lib/PackageKit/
# var/lib/git/
# var/lib/man-db/
# var/lib/man-db/auto-update
# var/lib/vim/
# var/lib/vim/addons/
# var/lib/dbus/
# var/lib/dbus/machine-id
# var/lib/python/
# var/lib/python/python3.10_installed
# var/lib/python/python3.8_installed
# var/lib/ucf/
# var/lib/ucf/hashfile.1
# var/lib/ucf/hashfile.0
# var/lib/ucf/cache/
# var/lib/ucf/cache/:etc:R:Renviron
# var/lib/ucf/cache/:etc:papersize
# var/lib/ucf/hashfile.2
# var/lib/ucf/hashfile
# var/lib/ucf/registry.0
# var/lib/ucf/registry
# var/cache/
# var/cache/apt/
# var/cache/apt/archives/
# var/cache/apt/archives/partial/
# var/cache/apt/archives/lock
# var/cache/debconf/
# var/cache/debconf/templates.dat
# var/cache/debconf/config.dat
# var/cache/debconf/passwords.dat
# var/cache/debconf/config.dat-old
# var/cache/debconf/templates.dat-old
# var/cache/ldconfig/
# var/cache/ldconfig/aux-cache
# var/cache/man/
# var/cache/man/sv/
# var/cache/man/sv/index.db
# var/cache/man/sv/cat1/
# var/cache/man/sv/cat5/
# var/cache/man/sv/cat8/
# var/cache/man/sv/CACHEDIR.TAG
# var/cache/man/zh_TW/
# var/cache/man/zh_TW/index.db
# var/cache/man/zh_TW/cat1/
# var/cache/man/zh_TW/CACHEDIR.TAG
# var/cache/man/da/
# var/cache/man/da/index.db
# var/cache/man/da/cat1/
# var/cache/man/da/cat5/
# var/cache/man/da/cat8/
# var/cache/man/da/CACHEDIR.TAG
# var/cache/man/index.db
# var/cache/man/es/
# var/cache/man/es/index.db
# var/cache/man/es/cat1/
# var/cache/man/es/cat5/
# var/cache/man/es/cat8/
# var/cache/man/es/CACHEDIR.TAG
# var/cache/man/nl/
# var/cache/man/nl/index.db
# var/cache/man/nl/cat1/
# var/cache/man/nl/cat5/
# var/cache/man/nl/cat8/
# var/cache/man/nl/CACHEDIR.TAG
# var/cache/man/cat6/
# var/cache/man/pt_BR/
# var/cache/man/pt_BR/index.db
# var/cache/man/pt_BR/cat1/
# var/cache/man/pt_BR/cat5/
# var/cache/man/pt_BR/cat8/
# var/cache/man/pt_BR/CACHEDIR.TAG
# var/cache/man/ko/
# var/cache/man/ko/index.db
# var/cache/man/ko/cat1/
# var/cache/man/ko/CACHEDIR.TAG
# var/cache/man/sr/
# var/cache/man/sr/index.db
# var/cache/man/sr/cat1/
# var/cache/man/sr/cat5/
# var/cache/man/sr/cat8/
# var/cache/man/sr/CACHEDIR.TAG
# var/cache/man/tr/
# var/cache/man/tr/index.db
# var/cache/man/tr/cat1/
# var/cache/man/tr/cat5/
# var/cache/man/tr/cat8/
# var/cache/man/tr/CACHEDIR.TAG
# var/cache/man/ja/
# var/cache/man/ja/index.db
# var/cache/man/ja/cat1/
# var/cache/man/ja/cat5/
# var/cache/man/ja/cat8/
# var/cache/man/ja/CACHEDIR.TAG
# var/cache/man/zh_CN/
# var/cache/man/zh_CN/index.db
# var/cache/man/zh_CN/cat1/
# var/cache/man/zh_CN/cat5/
# var/cache/man/zh_CN/cat8/
# var/cache/man/zh_CN/CACHEDIR.TAG
# var/cache/man/de/
# var/cache/man/de/index.db
# var/cache/man/de/cat1/
# var/cache/man/de/cat5/
# var/cache/man/de/cat8/
# var/cache/man/de/CACHEDIR.TAG
# var/cache/man/cat1/
# var/cache/man/cat2/
# var/cache/man/cat3/
# var/cache/man/ru/
# var/cache/man/ru/index.db
# var/cache/man/ru/cat1/
# var/cache/man/ru/cat5/
# var/cache/man/ru/cat8/
# var/cache/man/ru/CACHEDIR.TAG
# var/cache/man/fr/
# var/cache/man/fr/index.db
# var/cache/man/fr/cat1/
# var/cache/man/fr/cat5/
# var/cache/man/fr/cat8/
# var/cache/man/fr/CACHEDIR.TAG
# var/cache/man/pt/
# var/cache/man/pt/index.db
# var/cache/man/pt/cat1/
# var/cache/man/pt/cat5/
# var/cache/man/pt/cat8/
# var/cache/man/pt/CACHEDIR.TAG
# var/cache/man/cat4/
# var/cache/man/cat5/
# var/cache/man/pl/
# var/cache/man/pl/index.db
# var/cache/man/pl/cat1/
# var/cache/man/pl/cat5/
# var/cache/man/pl/cat8/
# var/cache/man/pl/CACHEDIR.TAG
# var/cache/man/cat8/
# var/cache/man/hu/
# var/cache/man/hu/index.db
# var/cache/man/hu/cat1/
# var/cache/man/hu/CACHEDIR.TAG
# var/cache/man/CACHEDIR.TAG
# var/cache/man/id/
# var/cache/man/id/index.db
# var/cache/man/id/cat1/
# var/cache/man/id/cat5/
# var/cache/man/id/cat8/
# var/cache/man/id/CACHEDIR.TAG
# var/cache/man/it/
# var/cache/man/it/index.db
# var/cache/man/it/cat1/
# var/cache/man/it/cat5/
# var/cache/man/it/cat8/
# var/cache/man/it/CACHEDIR.TAG
# var/cache/man/cs/
# var/cache/man/cs/index.db
# var/cache/man/cs/cat1/
# var/cache/man/cs/cat5/
# var/cache/man/cs/cat8/
# var/cache/man/cs/CACHEDIR.TAG
# var/cache/man/cat7/
# var/cache/private/
# var/cache/PackageKit/
# var/cache/PackageKit/downloads/
# var/cache/fontconfig/
# var/cache/fontconfig/d14b28ba-94fc-4951-b861-17e1a0aea65b-le64.cache-7
# var/cache/fontconfig/15f19334-91f3-4bf8-b19c-f73f5f867a66-le64.cache-7
# var/cache/fontconfig/4f65b3c4-8fbb-4840-8f58-0bb27881f87b-le64.cache-7
# var/cache/fontconfig/5fa5eb82-8ac2-4e0a-89f5-f2ee4b418845-le64.cache-7
# var/cache/fontconfig/CACHEDIR.TAG
# var/cache/fontconfig/c139b66f-0f63-4bf5-b601-b01685d8284b-le64.cache-7
# var/log/
# var/log/faillog
# var/log/apt/
# var/log/apt/eipp.log.xz
# var/log/apt/history.log.bak-run.sh
# var/log/apt/term.log
# var/log/bootstrap.log
# var/log/alternatives.log
# var/log/lastlog
# var/log/wtmp
# var/log/btmp
# var/log/dpkg.log
# var/log/pip.log.bak-run.sh
# var/log/pip.log
# var/log/journal/
# var/log/private/
# var/log/fontconfig.log
# var/local/
# var/opt/
# var/mail/
# var/lock
# var/colab/
# var/colab/lsp.3.log
# var/colab/lsp.2.log
# var/colab/lsp.1.log
# var/colab/app.log
# var/colab/cgroup/
# var/colab/cgroup/jupyter-children/
# var/colab/cgroup/jupyter-children/cgroup.events
# var/colab/cgroup/jupyter-children/memory.events
# var/colab/cgroup/jupyter-children/io.pressure
# var/colab/cgroup/jupyter-children/cgroup.procs
# var/colab/cgroup/jupyter-children/memory.events.local
# var/colab/cgroup/jupyter-children/memory.swap.current
# var/colab/cgroup/jupyter-children/memory.swap.max
# var/colab/cgroup/jupyter-children/cpu.weight
# var/colab/cgroup/jupyter-children/memory.swap.events
# var/colab/cgroup/jupyter-children/cgroup.max.descendants
# var/colab/cgroup/jupyter-children/cpu.stat
# var/colab/cgroup/jupyter-children/cpu.weight.nice
# var/colab/cgroup/jupyter-children/memory.pressure
# var/colab/cgroup/jupyter-children/memory.current
# var/colab/cgroup/jupyter-children/pids.current
# var/colab/cgroup/jupyter-children/memory.stat
# var/colab/cgroup/jupyter-children/pids.events
# var/colab/cgroup/jupyter-children/memory.low
# var/colab/cgroup/jupyter-children/cpu.pressure
# var/colab/cgroup/jupyter-children/cgroup.type
# var/colab/cgroup/jupyter-children/cgroup.stat
# var/colab/cgroup/jupyter-children/hugetlb.1GB.events.local
# var/colab/cgroup/jupyter-children/rdma.current
# var/colab/cgroup/jupyter-children/memory.swap.high
# var/colab/cgroup/jupyter-children/hugetlb.2MB.rsvd.max
# var/colab/cgroup/jupyter-children/cpu.idle
# var/colab/cgroup/jupyter-children/hugetlb.1GB.rsvd.current
# var/colab/cgroup/jupyter-children/rdma.max
# var/colab/cgroup/jupyter-children/hugetlb.2MB.events
# var/colab/cgroup/jupyter-children/cgroup.threads
# var/colab/cgroup/jupyter-children/memory.numa_stat
# var/colab/cgroup/jupyter-children/cgroup.kill
# var/colab/cgroup/jupyter-children/hugetlb.1GB.rsvd.max
# var/colab/cgroup/jupyter-children/hugetlb.2MB.current
# var/colab/cgroup/jupyter-children/cpuset.cpus.partition
# var/colab/cgroup/jupyter-children/cpuset.cpus.effective
# var/colab/cgroup/jupyter-children/hugetlb.1GB.max
# var/colab/cgroup/jupyter-children/cgroup.freeze
# var/colab/cgroup/jupyter-children/memory.min
# var/colab/cgroup/jupyter-children/cpu.max.burst
# var/colab/cgroup/jupyter-children/cgroup.controllers
# var/colab/cgroup/jupyter-children/cpu.max
# var/colab/cgroup/jupyter-children/hugetlb.2MB.events.local
# var/colab/cgroup/jupyter-children/memory.oom.group
# var/colab/cgroup/jupyter-children/memory.max
# var/colab/cgroup/jupyter-children/cpuset.mems
# var/colab/cgroup/jupyter-children/memory.high
# var/colab/cgroup/jupyter-children/pids.max
# var/colab/cgroup/jupyter-children/cpuset.mems.effective
# var/colab/cgroup/jupyter-children/cgroup.subtree_control
# var/colab/cgroup/jupyter-children/io.max
# var/colab/cgroup/jupyter-children/hugetlb.1GB.events
# var/colab/cgroup/jupyter-children/hugetlb.1GB.current
# var/colab/cgroup/jupyter-children/hugetlb.2MB.rsvd.current
# var/colab/cgroup/jupyter-children/cpuset.cpus
# var/colab/cgroup/jupyter-children/cgroup.max.depth
# var/colab/cgroup/jupyter-children/io.stat
# var/colab/cgroup/jupyter-children/hugetlb.2MB.max
# var/colab/next-container-tag
# var/colab/default-container-tag
# var/colab/hostname
# tar: Exiting with failure status due to previous errors
# /

# %%
from google.colab import files
files.download('mifgsm.tgz')

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 20))
cnt = 0
for i, cls_name in enumerate(classes):
    path = f'{cls_name}/{cls_name}1.png'
    # benign image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./data/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'benign: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
    # adversarial image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./fgsm/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'adversarial: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-67-5d5b8cd7b95e> in <cell line: 7>()
#      10     cnt += 1
#      11     plt.subplot(len(classes), 4, cnt)
# ---> 12     im = Image.open(f'./data/{path}')
#      13     logit = model(transform(im).unsqueeze(0).to(device))[0]
#      14     predict = logit.argmax(-1).item()
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/airplane/airplane1.png'

# %% [markdown]
# ## Report Question
# * Make sure you follow below setup: the source model is "resnet110_cifar10", applying the vanilla fgsm attack on `dog2.png`. You can find the perturbed image in `fgsm/dog2.png`.

# %%
# original image
path = f'dog/dog2.png'
im = Image.open(f'./data/{path}')
logit = model(transform(im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'benign: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(im))
plt.tight_layout()
plt.show()

# adversarial image 
adv_im = Image.open(f'./fgsm/{path}')
logit = model(transform(adv_im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(adv_im))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Passive Defense - JPEG compression
# JPEG compression by imgaug package, compression rate set to 70
#
# Reference: https://imgaug.readthedocs.io/en/latest/source/api_augmenters_arithmetic.html#imgaug.augmenters.arithmetic.JpegCompression
#
# Note: If you haven't implemented the JPEG compression, this module will return an error. Don't worry about this.

# %%
import imgaug.augmenters as iaa

# pre-process image
x = transforms.ToTensor()(adv_im)*255
x = x.permute(1, 2, 0).numpy()
x = x.astype(np.uint8)

# TODO: use "imgaug" package to perform JPEG compression (compression rate = 70)
# compressed_x =  ... x .. 
aug=iaa.JpegCompression(compression=70)
compressed_x=aug.augment_image(x)

logit = model(transform(compressed_x).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'JPEG adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')


plt.imshow(compressed_x)
plt.tight_layout()
plt.show()
